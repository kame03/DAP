# %%
import pandas as pd
import json
from pymongo import MongoClient
from pprint import pprint
client = MongoClient('localhost', 27017)
db = client['db_project']
collection_dap = db['project']

with open('Inp.json') as f:
    file_data = json.load(f)
    
for k in file_data:
    collection_dap.insert_one(k)

    
for r in collection_dap.find({}):
    pprint(r)
# if pymongo >= 3.0 use insert_one() for inserting one document
#collection_dap.insert_one(file_data)


client.close()
# Out:
# {'Average Covered Charges': '$32963.07',
#  'Average Medicare Payments': '$4763.73',
#  'Average Total Payments': '$5777.24',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AL - Dothan',
#  'Provider City': 'DOTHAN',
#  'Provider Id': 10001,
#  'Provider Name': 'SOUTHEAST ALABAMA MEDICAL CENTER',
#  'Provider State': 'AL',
#  'Provider Street Address': '1108 ROSS CLARK CIRCLE',
#  'Provider Zip Code': 36301,
#  'Total Discharges': 91,
#  '_id': ObjectId('5ea5b7403b3975ff34d9ca84')}
# {'Average Covered Charges': '$15131.85',
#  'Average Medicare Payments': '$4976.71',
#  'Average Total Payments': '$5787.57',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AL - Birmingham',
#  'Provider City': 'BOAZ',
#  'Provider Id': 10005,
#  'Provider Name': 'MARSHALL MEDICAL CENTER SOUTH',
#  'Provider State': 'AL',
#  'Provider Street Address': '2505 U S HIGHWAY 431 NORTH',
#  'Provider Zip Code': 35957,
#  'Total Discharges': 14,
#  '_id': ObjectId('5ea5b7403b3975ff34d9ca85')}
# {'Average Covered Charges': '$37560.37',
#  'Average Medicare Payments': '$4453.79',
#  'Average Total Payments': '$5434.95',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AL - Birmingham',
#  'Provider City': 'FLORENCE',
#  'Provider Id': 10006,
#  'Provider Name': 'ELIZA COFFEE MEMORIAL HOSPITAL',
#  'Provider State': 'AL',
#  'Provider Street Address': '205 MARENGO STREET',
#  'Provider Zip Code': 35631,
#  'Total Discharges': 24,
#  '_id': ObjectId('5ea5b7403b3975ff34d9ca86')}
# {'Average Covered Charges': '$13998.28',
#  'Average Medicare Payments': '$4129.16',
#  'Average Total Payments': '$5417.56',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AL - Birmingham',
#  'Provider City': 'BIRMINGHAM',
#  'Provider Id': 10011,
#  'Provider Name': "ST VINCENT'S EAST",
#  'Provider State': 'AL',
#  'Provider Street Address': '50 MEDICAL PARK EAST DRIVE',
#  'Provider Zip Code': 35235,
#  'Total Discharges': 25,
#  '_id': ObjectId('5ea5b7403b3975ff34d9ca87')}
# {'Average Covered Charges': '$31633.27',
#  'Average Medicare Payments': '$4851.44',
#  'Average Total Payments': '$5658.33',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AL - Birmingham',
#  'Provider City': 'ALABASTER',
#  'Provider Id': 10016,
#  'Provider Name': 'SHELBY BAPTIST MEDICAL CENTER',
#  'Provider State': 'AL',
#  'Provider Street Address': '1000 FIRST STREET NORTH',
#  'Provider Zip Code': 35007,
#  'Total Discharges': 18,
#  '_id': ObjectId('5ea5b7403b3975ff34d9ca88')}
# {'Average Covered Charges': '$16920.79',
#  'Average Medicare Payments': '$5374.14',
#  'Average Total Payments': '$6653.80',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AL - Montgomery',
#  'Provider City': 'MONTGOMERY',
#  'Provider Id': 10023,
#  'Provider Name': 'BAPTIST MEDICAL CENTER SOUTH',
#  'Provider State': 'AL',
#  'Provider Street Address': '2105 EAST SOUTH BOULEVARD',
#  'Provider Zip Code': 36116,
#  'Total Discharges': 67,
#  '_id': ObjectId('5ea5b7403b3975ff34d9ca89')}
# {'Average Covered Charges': '$11977.13',
#  'Average Medicare Payments': '$4761.41',
#  'Average Total Payments': '$5834.74',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AL - Birmingham',
#  'Provider City': 'OPELIKA',
#  'Provider Id': 10029,
#  'Provider Name': 'EAST ALABAMA MEDICAL CENTER AND SNF',
#  'Provider State': 'AL',
#  'Provider Street Address': '2000 PEPPERELL PARKWAY',
#  'Provider Zip Code': 36801,
#  'Total Discharges': 51,
#  '_id': ObjectId('5ea5b7403b3975ff34d9ca8a')}
# {'Average Covered Charges': '$35841.09',
#  'Average Medicare Payments': '$5858.50',
#  'Average Total Payments': '$8031.12',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AL - Birmingham',
#  'Provider City': 'BIRMINGHAM',
#  'Provider Id': 10033,
#  'Provider Name': 'UNIVERSITY OF ALABAMA HOSPITAL',
#  'Provider State': 'AL',
#  'Provider Street Address': '619 SOUTH 19TH STREET',
#  'Provider Zip Code': 35233,
#  'Total Discharges': 32,
#  '_id': ObjectId('5ea5b7403b3975ff34d9ca8b')}
# {'Average Covered Charges': '$28523.39',
#  'Average Medicare Payments': '$5228.40',
#  'Average Total Payments': '$6113.38',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AL - Huntsville',
#  'Provider City': 'HUNTSVILLE',
#  'Provider Id': 10039,
#  'Provider Name': 'HUNTSVILLE HOSPITAL',
#  'Provider State': 'AL',
#  'Provider Street Address': '101 SIVLEY RD',
#  'Provider Zip Code': 35801,
#  'Total Discharges': 135,
#  '_id': ObjectId('5ea5b7403b3975ff34d9ca8c')}
# {'Average Covered Charges': '$75233.38',
#  'Average Medicare Payments': '$4386.94',
#  'Average Total Payments': '$5541.05',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AL - Birmingham',
#  'Provider City': 'GADSDEN',
#  'Provider Id': 10040,
#  'Provider Name': 'GADSDEN REGIONAL MEDICAL CENTER',
#  'Provider State': 'AL',
#  'Provider Street Address': '1007 GOODYEAR AVENUE',
#  'Provider Zip Code': 35903,
#  'Total Discharges': 34,
#  '_id': ObjectId('5ea5b7403b3975ff34d9ca8d')}
# {'Average Covered Charges': '$67327.92',
#  'Average Medicare Payments': '$4493.57',
#  'Average Total Payments': '$5461.57',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AL - Birmingham',
#  'Provider City': 'GADSDEN',
#  'Provider Id': 10046,
#  'Provider Name': 'RIVERVIEW REGIONAL MEDICAL CENTER',
#  'Provider State': 'AL',
#  'Provider Street Address': '600 SOUTH THIRD STREET',
#  'Provider Zip Code': 35901,
#  'Total Discharges': 14,
#  '_id': ObjectId('5ea5b7403b3975ff34d9ca8e')}
# {'Average Covered Charges': '$39607.28',
#  'Average Medicare Payments': '$4408.20',
#  'Average Total Payments': '$5356.28',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AL - Dothan',
#  'Provider City': 'DOTHAN',
#  'Provider Id': 10055,
#  'Provider Name': 'FLOWERS HOSPITAL',
#  'Provider State': 'AL',
#  'Provider Street Address': '4370 WEST MAIN STREET',
#  'Provider Zip Code': 36305,
#  'Total Discharges': 45,
#  '_id': ObjectId('5ea5b7403b3975ff34d9ca8f')}
# {'Average Covered Charges': '$22862.23',
#  'Average Medicare Payments': '$4186.02',
#  'Average Total Payments': '$5374.65',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AL - Birmingham',
#  'Provider City': 'BIRMINGHAM',
#  'Provider Id': 10056,
#  'Provider Name': "ST VINCENT'S BIRMINGHAM",
#  'Provider State': 'AL',
#  'Provider Street Address': "810 ST VINCENT'S DRIVE",
#  'Provider Zip Code': 35205,
#  'Total Discharges': 43,
#  '_id': ObjectId('5ea5b7403b3975ff34d9ca90')}
# {'Average Covered Charges': '$31110.85',
#  'Average Medicare Payments': '$4376.23',
#  'Average Total Payments': '$5366.23',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AL - Birmingham',
#  'Provider City': 'ANNISTON',
#  'Provider Id': 10078,
#  'Provider Name': 'NORTHEAST ALABAMA REGIONAL MED CENTER',
#  'Provider State': 'AL',
#  'Provider Street Address': '400 EAST 10TH STREET',
#  'Provider Zip Code': 36207,
#  'Total Discharges': 21,
#  '_id': ObjectId('5ea5b7403b3975ff34d9ca91')}
# {'Average Covered Charges': '$25411.33',
#  'Average Medicare Payments': '$4383.73',
#  'Average Total Payments': '$5282.93',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AL - Mobile',
#  'Provider City': 'FOLEY',
#  'Provider Id': 10083,
#  'Provider Name': 'SOUTH BALDWIN REGIONAL MEDICAL CENTER',
#  'Provider State': 'AL',
#  'Provider Street Address': '1613 NORTH MCKENZIE STREET',
#  'Provider Zip Code': 36535,
#  'Total Discharges': 15,
#  '_id': ObjectId('5ea5b7403b3975ff34d9ca92')}
# {'Average Covered Charges': '$9234.51',
#  'Average Medicare Payments': '$4509.11',
#  'Average Total Payments': '$5676.55',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AL - Huntsville',
#  'Provider City': 'DECATUR',
#  'Provider Id': 10085,
#  'Provider Name': 'DECATUR GENERAL HOSPITAL',
#  'Provider State': 'AL',
#  'Provider Street Address': '1201 7TH STREET SE',
#  'Provider Zip Code': 35609,
#  'Total Discharges': 27,
#  '_id': ObjectId('5ea5b7403b3975ff34d9ca93')}
# {'Average Covered Charges': '$15895.85',
#  'Average Medicare Payments': '$3972.85',
#  'Average Total Payments': '$5930.11',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AL - Mobile',
#  'Provider City': 'MOBILE',
#  'Provider Id': 10090,
#  'Provider Name': 'PROVIDENCE HOSPITAL',
#  'Provider State': 'AL',
#  'Provider Street Address': '6801 AIRPORT BOULEVARD',
#  'Provider Zip Code': 36608,
#  'Total Discharges': 27,
#  '_id': ObjectId('5ea5b7403b3975ff34d9ca94')}
# {'Average Covered Charges': '$19721.16',
#  'Average Medicare Payments': '$5179.38',
#  'Average Total Payments': '$6192.54',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AL - Tuscaloosa',
#  'Provider City': 'TUSCALOOSA',
#  'Provider Id': 10092,
#  'Provider Name': 'D C H REGIONAL MEDICAL CENTER',
#  'Provider State': 'AL',
#  'Provider Street Address': '809 UNIVERSITY BOULEVARD EAST',
#  'Provider Zip Code': 35401,
#  'Total Discharges': 31,
#  '_id': ObjectId('5ea5b7403b3975ff34d9ca95')}
# {'Average Covered Charges': '$10710.88',
#  'Average Medicare Payments': '$3898.88',
#  'Average Total Payments': '$4968.00',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AL - Mobile',
#  'Provider City': 'FAIRHOPE',
#  'Provider Id': 10100,
#  'Provider Name': 'THOMAS HOSPITAL',
#  'Provider State': 'AL',
#  'Provider Street Address': '750 MORPHY AVENUE',
#  'Provider Zip Code': 36532,
#  'Total Discharges': 18,
#  '_id': ObjectId('5ea5b7403b3975ff34d9ca96')}
# {'Average Covered Charges': '$51343.75',
#  'Average Medicare Payments': '$4962.45',
#  'Average Total Payments': '$5996.00',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AL - Birmingham',
#  'Provider City': 'BIRMINGHAM',
#  'Provider Id': 10103,
#  'Provider Name': 'BAPTIST MEDICAL CENTER-PRINCETON',
#  'Provider State': 'AL',
#  'Provider Street Address': '701 PRINCETON AVENUE SOUTHWEST',
#  'Provider Zip Code': 35211,
#  'Total Discharges': 33,
#  '_id': ObjectId('5ea5b7403b3975ff34d9ca97')}
# {'Average Covered Charges': '$55219.31',
#  'Average Medicare Payments': '$4471.68',
#  'Average Total Payments': '$5710.31',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AL - Birmingham',
#  'Provider City': 'BIRMINGHAM',
#  'Provider Id': 10104,
#  'Provider Name': 'TRINITY MEDICAL CENTER',
#  'Provider State': 'AL',
#  'Provider Street Address': '800 MONTCLAIR RD',
#  'Provider Zip Code': 35213,
#  'Total Discharges': 29,
#  '_id': ObjectId('5ea5b7403b3975ff34d9ca98')}
# {'Average Covered Charges': '$14948.15',
#  'Average Medicare Payments': '$4219.90',
#  'Average Total Payments': '$5550.90',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AL - Mobile',
#  'Provider City': 'MOBILE',
#  'Provider Id': 10113,
#  'Provider Name': 'MOBILE INFIRMARY',
#  'Provider State': 'AL',
#  'Provider Street Address': '5 MOBILE INFIRMARY CIRCLE',
#  'Provider Zip Code': 36652,
#  'Total Discharges': 66,
#  '_id': ObjectId('5ea5b7403b3975ff34d9ca99')}
# {'Average Covered Charges': '$73846.21',
#  'Average Medicare Payments': '$3944.42',
#  'Average Total Payments': '$4987.26',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AL - Birmingham',
#  'Provider City': 'BIRMINGHAM',
#  'Provider Id': 10139,
#  'Provider Name': 'BROOKWOOD MEDICAL CENTER',
#  'Provider State': 'AL',
#  'Provider Street Address': '2010 BROOKWOOD MEDICAL CENTER DRIVE',
#  'Provider Zip Code': 35209,
#  'Total Discharges': 19,
#  '_id': ObjectId('5ea5b7403b3975ff34d9ca9a')}
# {'Average Covered Charges': '$34805.13',
#  'Average Medicare Payments': '$6413.78',
#  'Average Total Payments': '$8401.95',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AK - Anchorage',
#  'Provider City': 'ANCHORAGE',
#  'Provider Id': 20017,
#  'Provider Name': 'ALASKA REGIONAL HOSPITAL',
#  'Provider State': 'AK',
#  'Provider Street Address': '2801 DEBARR ROAD',
#  'Provider Zip Code': 99508,
#  'Total Discharges': 23,
#  '_id': ObjectId('5ea5b7403b3975ff34d9ca9b')}
# {'Average Covered Charges': '$34803.81',
#  'Average Medicare Payments': '$6951.45',
#  'Average Total Payments': '$7768.90',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AZ - Phoenix',
#  'Provider City': 'PHOENIX',
#  'Provider Id': 30002,
#  'Provider Name': 'BANNER GOOD SAMARITAN MEDICAL CENTER',
#  'Provider State': 'AZ',
#  'Provider Street Address': '1111 EAST MCDOWELL ROAD',
#  'Provider Zip Code': 85006,
#  'Total Discharges': 11,
#  '_id': ObjectId('5ea5b7403b3975ff34d9ca9c')}
# {'Average Covered Charges': '$24474.75',
#  'Average Medicare Payments': '$5764.87',
#  'Average Total Payments': '$6799.85',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AZ - Tucson',
#  'Provider City': 'TUCSON',
#  'Provider Id': 30006,
#  'Provider Name': 'TUCSON MEDICAL CENTER',
#  'Provider State': 'AZ',
#  'Provider Street Address': '5301 EAST GRANT ROAD',
#  'Provider Zip Code': 85712,
#  'Total Discharges': 40,
#  '_id': ObjectId('5ea5b7403b3975ff34d9ca9d')}
# {'Average Covered Charges': '$28571.61',
#  'Average Medicare Payments': '$8008.11',
#  'Average Total Payments': '$9133.00',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AZ - Phoenix',
#  'Provider City': 'COTTONWOOD',
#  'Provider Id': 30007,
#  'Provider Name': 'VERDE VALLEY MEDICAL CENTER',
#  'Provider State': 'AZ',
#  'Provider Street Address': '269 SOUTH CANDY LANE',
#  'Provider Zip Code': 86326,
#  'Total Discharges': 18,
#  '_id': ObjectId('5ea5b7403b3975ff34d9ca9e')}
# {'Average Covered Charges': '$35968.50',
#  'Average Medicare Payments': '$5379.83',
#  'Average Total Payments': '$6506.50',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AZ - Tucson',
#  'Provider City': 'TUCSON',
#  'Provider Id': 30010,
#  'Provider Name': 'CARONDELET ST  MARYS HOSPITAL',
#  'Provider State': 'AZ',
#  'Provider Street Address': "1601 WEST ST MARY'S ROAD",
#  'Provider Zip Code': 85745,
#  'Total Discharges': 12,
#  '_id': ObjectId('5ea5b7403b3975ff34d9ca9f')}
# {'Average Covered Charges': '$26294.52',
#  'Average Medicare Payments': '$4903.33',
#  'Average Total Payments': '$6083.42',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AZ - Tucson',
#  'Provider City': 'TUCSON',
#  'Provider Id': 30011,
#  'Provider Name': 'CARONDELET ST JOSEPHS HOSPITAL',
#  'Provider State': 'AZ',
#  'Provider Street Address': '350 NORTH WILMOT ROAD',
#  'Provider Zip Code': 85711,
#  'Total Discharges': 42,
#  '_id': ObjectId('5ea5b7403b3975ff34d9caa0')}
# {'Average Covered Charges': '$26771.78',
#  'Average Medicare Payments': '$6133.57',
#  'Average Total Payments': '$7140.85',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AZ - Phoenix',
#  'Provider City': 'PRESCOTT',
#  'Provider Id': 30012,
#  'Provider Name': 'YAVAPAI REGIONAL MEDICAL CENTER',
#  'Provider State': 'AZ',
#  'Provider Street Address': '1003 WILLOW CREEK ROAD',
#  'Provider Zip Code': 86301,
#  'Total Discharges': 28,
#  '_id': ObjectId('5ea5b7403b3975ff34d9caa1')}
# {'Average Covered Charges': '$29967.80',
#  'Average Medicare Payments': '$5969.55',
#  'Average Total Payments': '$6978.75',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AZ - Phoenix',
#  'Provider City': 'YUMA',
#  'Provider Id': 30013,
#  'Provider Name': 'YUMA REGIONAL MEDICAL CENTER',
#  'Provider State': 'AZ',
#  'Provider Street Address': '2400 SOUTH AVENUE A',
#  'Provider Zip Code': 85364,
#  'Total Discharges': 20,
#  '_id': ObjectId('5ea5b7403b3975ff34d9caa2')}
# {'Average Covered Charges': '$27349.40',
#  'Average Medicare Payments': '$9056.06',
#  'Average Total Payments': '$11026.33',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AZ - Phoenix',
#  'Provider City': 'FLAGSTAFF',
#  'Provider Id': 30023,
#  'Provider Name': 'FLAGSTAFF MEDICAL CENTER',
#  'Provider State': 'AZ',
#  'Provider Street Address': '1200 NORTH BEAVER STREET',
#  'Provider Zip Code': 86001,
#  'Total Discharges': 15,
#  '_id': ObjectId('5ea5b7403b3975ff34d9caa3')}
# {'Average Covered Charges': '$59443.83',
#  'Average Medicare Payments': '$7422.66',
#  'Average Total Payments': '$8487.44',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AZ - Phoenix',
#  'Provider City': 'PHOENIX',
#  'Provider Id': 30024,
#  'Provider Name': "ST JOSEPH'S HOSPITAL AND MEDICAL CENTER",
#  'Provider State': 'AZ',
#  'Provider Street Address': '350 WEST THOMAS ROAD',
#  'Provider Zip Code': 85013,
#  'Total Discharges': 18,
#  '_id': ObjectId('5ea5b7403b3975ff34d9caa4')}
# {'Average Covered Charges': '$24714.66',
#  'Average Medicare Payments': '$6541.92',
#  'Average Total Payments': '$7673.21',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AZ - Phoenix',
#  'Provider City': 'PHOENIX',
#  'Provider Id': 30030,
#  'Provider Name': 'PHOENIX BAPTIST HOSPITAL',
#  'Provider State': 'AZ',
#  'Provider Street Address': '2000 WEST BETHANY HOME ROAD',
#  'Provider Zip Code': 85015,
#  'Total Discharges': 42,
#  '_id': ObjectId('5ea5b7403b3975ff34d9caa5')}
# {'Average Covered Charges': '$37706.00',
#  'Average Medicare Payments': '$5473.00',
#  'Average Total Payments': '$6590.23',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AZ - Phoenix',
#  'Provider City': 'SCOTTSDALE',
#  'Provider Id': 30038,
#  'Provider Name': 'SCOTTSDALE HEALTHCARE-OSBORN MEDICAL CENTER',
#  'Provider State': 'AZ',
#  'Provider Street Address': '7400 EAST OSBORN ROAD',
#  'Provider Zip Code': 85251,
#  'Total Discharges': 13,
#  '_id': ObjectId('5ea5b7403b3975ff34d9caa6')}
# {'Average Covered Charges': '$38149.85',
#  'Average Medicare Payments': '$4951.90',
#  'Average Total Payments': '$6048.61',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AZ - Sun City',
#  'Provider City': 'SUN CITY',
#  'Provider Id': 30061,
#  'Provider Name': 'BANNER BOSWELL MEDICAL CENTER',
#  'Provider State': 'AZ',
#  'Provider Street Address': '10401 WEST THUNDERBIRD BOULEVARD',
#  'Provider Zip Code': 85351,
#  'Total Discharges': 62,
#  '_id': ObjectId('5ea5b7403b3975ff34d9caa7')}
# {'Average Covered Charges': '$15931.52',
#  'Average Medicare Payments': '$7321.64',
#  'Average Total Payments': '$10000.82',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AZ - Phoenix',
#  'Provider City': 'SHOW LOW',
#  'Provider Id': 30062,
#  'Provider Name': 'SUMMIT HEALTHCARE REGIONAL MEDICAL CENTER',
#  'Provider State': 'AZ',
#  'Provider Street Address': '2200 SHOW LOW LAKE ROAD',
#  'Provider Zip Code': 85901,
#  'Total Discharges': 17,
#  '_id': ObjectId('5ea5b7403b3975ff34d9caa8')}
# {'Average Covered Charges': '$29718.48',
#  'Average Medicare Payments': '$4846.36',
#  'Average Total Payments': '$7551.40',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AZ - Mesa',
#  'Provider City': 'MESA',
#  'Provider Id': 30065,
#  'Provider Name': 'BANNER DESERT MEDICAL CENTER',
#  'Provider State': 'AZ',
#  'Provider Street Address': '1400 SOUTH  DOBSON ROAD',
#  'Provider Zip Code': 85202,
#  'Total Discharges': 25,
#  '_id': ObjectId('5ea5b7403b3975ff34d9caa9')}
# {'Average Covered Charges': '$25259.66',
#  'Average Medicare Payments': '$5665.41',
#  'Average Total Payments': '$6605.19',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AZ - Phoenix',
#  'Provider City': 'LAKE HAVASU CIT',
#  'Provider Id': 30069,
#  'Provider Name': 'HAVASU REGIONAL MEDICAL CENTER',
#  'Provider State': 'AZ',
#  'Provider Street Address': '101 CIVIC CENTER LANE',
#  'Provider Zip Code': 86403,
#  'Total Discharges': 36,
#  '_id': ObjectId('5ea5b7403b3975ff34d9caaa')}
# {'Average Covered Charges': '$39165.92',
#  'Average Medicare Payments': '$5174.25',
#  'Average Total Payments': '$6051.18',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AZ - Phoenix',
#  'Provider City': 'SCOTTSDALE',
#  'Provider Id': 30087,
#  'Provider Name': 'SCOTTSDALE HEALTHCARE-SHEA MEDICAL CENTER',
#  'Provider State': 'AZ',
#  'Provider Street Address': '9003 EAST SHEA BOULEVARD',
#  'Provider Zip Code': 85260,
#  'Total Discharges': 27,
#  '_id': ObjectId('5ea5b7403b3975ff34d9caab')}
# {'Average Covered Charges': '$26776.33',
#  'Average Medicare Payments': '$5854.80',
#  'Average Total Payments': '$6907.06',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AZ - Phoenix',
#  'Provider City': 'GLENDALE',
#  'Provider Id': 30089,
#  'Provider Name': 'BANNER THUNDERBIRD MEDICAL CENTER',
#  'Provider State': 'AZ',
#  'Provider Street Address': '5555 WEST THUNDERBIRD ROAD',
#  'Provider Zip Code': 85306,
#  'Total Discharges': 15,
#  '_id': ObjectId('5ea5b7403b3975ff34d9caac')}
# {'Average Covered Charges': '$24560.00',
#  'Average Medicare Payments': '$5204.54',
#  'Average Total Payments': '$7079.36',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AZ - Phoenix',
#  'Provider City': 'PHOENIX',
#  'Provider Id': 30092,
#  'Provider Name': 'JOHN C LINCOLN DEER VALLEY HOSPITAL',
#  'Provider State': 'AZ',
#  'Provider Street Address': '19829 NORTH 27TH AVENUE',
#  'Provider Zip Code': 85027,
#  'Total Discharges': 11,
#  '_id': ObjectId('5ea5b7403b3975ff34d9caad')}
# {'Average Covered Charges': '$54050.58',
#  'Average Medicare Payments': '$5312.16',
#  'Average Total Payments': '$6061.50',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AZ - Sun City',
#  'Provider City': 'SUN CITY WEST',
#  'Provider Id': 30093,
#  'Provider Name': 'BANNER DEL E WEBB MEDICAL CENTER',
#  'Provider State': 'AZ',
#  'Provider Street Address': '14502 WEST MEEKER BOULEVARD',
#  'Provider Zip Code': 85375,
#  'Total Discharges': 12,
#  '_id': ObjectId('5ea5b7403b3975ff34d9caae')}
# {'Average Covered Charges': '$32998.00',
#  'Average Medicare Payments': '$6264.76',
#  'Average Total Payments': '$7046.00',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AZ - Phoenix',
#  'Provider City': 'GLENDALE',
#  'Provider Id': 30094,
#  'Provider Name': 'ARROWHEAD HOSPITAL',
#  'Provider State': 'AZ',
#  'Provider Street Address': '18701 NORTH 67TH AVENUE',
#  'Provider Zip Code': 85308,
#  'Total Discharges': 13,
#  '_id': ObjectId('5ea5b7403b3975ff34d9caaf')}
# {'Average Covered Charges': '$25757.64',
#  'Average Medicare Payments': '$3592.85',
#  'Average Total Payments': '$5976.00',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AZ - Tucson',
#  'Provider City': 'TUCSON',
#  'Provider Id': 30100,
#  'Provider Name': 'CARONDELET HEART AND VASCULAR INSTITUTE',
#  'Provider State': 'AZ',
#  'Provider Street Address': '4888 NORTH STONE AVENUE',
#  'Provider Zip Code': 85704,
#  'Total Discharges': 14,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cab0')}
# {'Average Covered Charges': '$60608.69',
#  'Average Medicare Payments': '$5652.65',
#  'Average Total Payments': '$6941.03',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'NV - Las Vegas',
#  'Provider City': 'BULLHEAD CITY',
#  'Provider Id': 30101,
#  'Provider Name': 'WESTERN ARIZONA REGIONAL MEDICAL CTR',
#  'Provider State': 'AZ',
#  'Provider Street Address': '2735 SILVER CREEK ROAD',
#  'Provider Zip Code': 86442,
#  'Total Discharges': 26,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cab1')}
# {'Average Covered Charges': '$29774.12',
#  'Average Medicare Payments': '$5674.20',
#  'Average Total Payments': '$7768.76',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AZ - Phoenix',
#  'Provider City': 'PHOENIX',
#  'Provider Id': 30103,
#  'Provider Name': 'MAYO CLINIC HOSPITAL',
#  'Provider State': 'AZ',
#  'Provider Street Address': '5777 EAST MAYO BOULEVARD',
#  'Provider Zip Code': 85054,
#  'Total Discharges': 25,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cab2')}
# {'Average Covered Charges': '$43823.20',
#  'Average Medicare Payments': '$4788.12',
#  'Average Total Payments': '$6291.95',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AZ - Mesa',
#  'Provider City': 'MESA',
#  'Provider Id': 30105,
#  'Provider Name': 'BANNER HEART HOSPITAL',
#  'Provider State': 'AZ',
#  'Provider Street Address': '6750 EAST BAYWOOD AVENUE',
#  'Provider Zip Code': 85206,
#  'Total Discharges': 64,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cab3')}
# {'Average Covered Charges': '$30470.56',
#  'Average Medicare Payments': '$4372.61',
#  'Average Total Payments': '$5811.56',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AR - Springdale',
#  'Provider City': 'FAYETTEVILLE',
#  'Provider Id': 40004,
#  'Provider Name': 'WASHINGTON REGIONAL MED CTR AT NORTH HILLS',
#  'Provider State': 'AR',
#  'Provider Street Address': '3215 N NORTH HILLS BLVD',
#  'Provider Zip Code': 72703,
#  'Total Discharges': 39,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cab4')}
# {'Average Covered Charges': '$27734.89',
#  'Average Medicare Payments': '$4837.54',
#  'Average Total Payments': '$6051.92',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AR - Little Rock',
#  'Provider City': 'LITTLE ROCK',
#  'Provider Id': 40007,
#  'Provider Name': 'ST VINCENT INFIRMARY MEDICAL CENTER',
#  'Provider State': 'AR',
#  'Provider Street Address': 'TWO ST VINCENT CIRCLE',
#  'Provider Zip Code': 72205,
#  'Total Discharges': 55,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cab5')}
# {'Average Covered Charges': '$17593.33',
#  'Average Medicare Payments': '$4576.33',
#  'Average Total Payments': '$5509.00',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AR - Springdale',
#  'Provider City': 'ROGERS',
#  'Provider Id': 40010,
#  'Provider Name': 'MERCY MEDICAL CENTER',
#  'Provider State': 'AR',
#  'Provider Street Address': '2710 RIFE MEDICAL LANE',
#  'Provider Zip Code': 72758,
#  'Total Discharges': 12,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cab6')}
# {'Average Covered Charges': '$11057.06',
#  'Average Medicare Payments': '$5247.85',
#  'Average Total Payments': '$6208.77',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AR - Jonesboro',
#  'Provider City': 'JONESBORO',
#  'Provider Id': 40020,
#  'Provider Name': 'ST BERNARDS MEDICAL CTR',
#  'Provider State': 'AR',
#  'Provider Street Address': '225 E JACKSON',
#  'Provider Zip Code': 72401,
#  'Total Discharges': 48,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cab7')}
# {'Average Covered Charges': '$37470.73',
#  'Average Medicare Payments': '$4234.68',
#  'Average Total Payments': '$6153.21',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AR - Springdale',
#  'Provider City': 'SPRINGDALE',
#  'Provider Id': 40022,
#  'Provider Name': 'NW ARKANSAS HOSPITALS, LLC',
#  'Provider State': 'AR',
#  'Provider Street Address': '609 WEST MAPLE AVENUE',
#  'Provider Zip Code': 72764,
#  'Total Discharges': 19,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cab8')}
# {'Average Covered Charges': '$19270.63',
#  'Average Medicare Payments': '$4759.70',
#  'Average Total Payments': '$5806.41',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AR - Little Rock',
#  'Provider City': 'HOT SPRINGS',
#  'Provider Id': 40026,
#  'Provider Name': 'ST JOSEPHS MERCY HEALTH CENTER INC',
#  'Provider State': 'AR',
#  'Provider Street Address': '300 WERNER STREET',
#  'Provider Zip Code': 71903,
#  'Total Discharges': 41,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cab9')}
# {'Average Covered Charges': '$16582.34',
#  'Average Medicare Payments': '$4424.64',
#  'Average Total Payments': '$5496.31',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'MO - Springfield',
#  'Provider City': 'MOUNTAIN HOME',
#  'Provider Id': 40027,
#  'Provider Name': 'BAXTER REGIONAL MEDICAL CENTER',
#  'Provider State': 'AR',
#  'Provider Street Address': '624 HOSPITAL DRIVE',
#  'Provider Zip Code': 72653,
#  'Total Discharges': 76,
#  '_id': ObjectId('5ea5b7413b3975ff34d9caba')}
# {'Average Covered Charges': '$11406.17',
#  'Average Medicare Payments': '$4569.41',
#  'Average Total Payments': '$5623.52',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AR - Little Rock',
#  'Provider City': 'CONWAY',
#  'Provider Id': 40029,
#  'Provider Name': 'CONWAY REGIONAL MEDICAL CENTER',
#  'Provider State': 'AR',
#  'Provider Street Address': '2302 COLLEGE AVENUE',
#  'Provider Zip Code': 72034,
#  'Total Discharges': 17,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cabb')}
# {'Average Covered Charges': '$23182.42',
#  'Average Medicare Payments': '$4622.34',
#  'Average Total Payments': '$5575.00',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AR - Little Rock',
#  'Provider City': 'NORTH LITTLE RO',
#  'Provider Id': 40036,
#  'Provider Name': 'BAPTIST HEALTH MEDICAL CENTER NORTH LITTLE ROCK',
#  'Provider State': 'AR',
#  'Provider Street Address': '3333 SPRINGHILL DRIVE',
#  'Provider Zip Code': 72117,
#  'Total Discharges': 35,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cabc')}
# {'Average Covered Charges': '$14799.30',
#  'Average Medicare Payments': '$4263.19',
#  'Average Total Payments': '$5489.53',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AR - Fort Smith',
#  'Provider City': 'FORT SMITH',
#  'Provider Id': 40062,
#  'Provider Name': 'ST EDWARD MERCY MEDICAL CENTER',
#  'Provider State': 'AR',
#  'Provider Street Address': '7301 ROGERS AVE',
#  'Provider Zip Code': 72917,
#  'Total Discharges': 26,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cabd')}
# {'Average Covered Charges': '$29474.08',
#  'Average Medicare Payments': '$5682.66',
#  'Average Total Payments': '$6529.00',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AR - Little Rock',
#  'Provider City': 'PINE BLUFF',
#  'Provider Id': 40071,
#  'Provider Name': 'JEFFERSON REGIONAL MEDICAL CENTER',
#  'Provider State': 'AR',
#  'Provider Street Address': '1600 WEST 40TH AVENUE',
#  'Provider Zip Code': 71603,
#  'Total Discharges': 12,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cabe')}
# {'Average Covered Charges': '$98388.77',
#  'Average Medicare Payments': '$8533.83',
#  'Average Total Payments': '$9838.11',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AR - Little Rock',
#  'Provider City': 'HOT SPRINGS',
#  'Provider Id': 40078,
#  'Provider Name': 'NATIONAL PARK MEDICAL CENTER',
#  'Provider State': 'AR',
#  'Provider Street Address': '1910 MALVERN AVENUE',
#  'Provider Zip Code': 71901,
#  'Total Discharges': 18,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cabf')}
# {'Average Covered Charges': '$25076.64',
#  'Average Medicare Payments': '$4592.46',
#  'Average Total Payments': '$5968.44',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AR - Little Rock',
#  'Provider City': 'LITTLE ROCK',
#  'Provider Id': 40114,
#  'Provider Name': 'BAPTIST HEALTH MEDICAL CENTER-LITTLE ROCK',
#  'Provider State': 'AR',
#  'Provider Street Address': '9601 INTERSTATE 630, EXIT 7',
#  'Provider Zip Code': 72205,
#  'Total Discharges': 139,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cac0')}
# {'Average Covered Charges': '$29442.36',
#  'Average Medicare Payments': '$5067.77',
#  'Average Total Payments': '$6451.86',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AR - Jonesboro',
#  'Provider City': 'JONESBORO',
#  'Provider Id': 40118,
#  'Provider Name': 'NEA BAPTIST MEMORIAL HOSPITAL',
#  'Provider State': 'AR',
#  'Provider Street Address': '3024 STADIUM BOULEVARD',
#  'Provider Zip Code': 72401,
#  'Total Discharges': 22,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cac1')}
# {'Average Covered Charges': '$22973.00',
#  'Average Medicare Payments': '$5166.29',
#  'Average Total Payments': '$6163.03',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AR - Little Rock',
#  'Provider City': 'BATESVILLE',
#  'Provider Id': 40119,
#  'Provider Name': 'WHITE RIVER MEDICAL CENTER',
#  'Provider State': 'AR',
#  'Provider Street Address': '1710 HARRISON STREET',
#  'Provider Zip Code': 72503,
#  'Total Discharges': 27,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cac2')}
# {'Average Covered Charges': '$24489.93',
#  'Average Medicare Payments': '$4068.10',
#  'Average Total Payments': '$5225.59',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'AR - Little Rock',
#  'Provider City': 'LITTLE ROCK',
#  'Provider Id': 40134,
#  'Provider Name': 'ARKANSAS HEART HOSPITAL',
#  'Provider State': 'AR',
#  'Provider Street Address': '1701 S SHACKLEFORD ROAD',
#  'Provider Zip Code': 72211,
#  'Total Discharges': 66,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cac3')}
# {'Average Covered Charges': '$44664.45',
#  'Average Medicare Payments': '$6936.52',
#  'Average Total Payments': '$8227.14',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'CA - Redding',
#  'Provider City': 'EUREKA',
#  'Provider Id': 50006,
#  'Provider Name': 'ST JOSEPH HOSPITAL',
#  'Provider State': 'CA',
#  'Provider Street Address': '2700 DOLBEER ST',
#  'Provider Zip Code': 95501,
#  'Total Discharges': 48,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cac4')}
# {'Average Covered Charges': '$51950.87',
#  'Average Medicare Payments': '$6872.50',
#  'Average Total Payments': '$7863.00',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'CA - San Mateo County',
#  'Provider City': 'BURLINGAME',
#  'Provider Id': 50007,
#  'Provider Name': 'PENINSULA MEDICAL CENTER',
#  'Provider State': 'CA',
#  'Provider Street Address': '1501 TROUSDALE DRIVE',
#  'Provider Zip Code': 94010,
#  'Total Discharges': 16,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cac5')}
# {'Average Covered Charges': '$105929.47',
#  'Average Medicare Payments': '$8376.35',
#  'Average Total Payments': '$9438.00',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'CA - Napa',
#  'Provider City': 'SAINT HELENA',
#  'Provider Id': 50013,
#  'Provider Name': 'ST HELENA HOSPITAL',
#  'Provider State': 'CA',
#  'Provider Street Address': '10 WOODLAND ROAD',
#  'Provider Zip Code': 94574,
#  'Total Discharges': 17,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cac6')}
# {'Average Covered Charges': '$66207.66',
#  'Average Medicare Payments': '$6924.70',
#  'Average Total Payments': '$10863.22',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'CA - Sacramento',
#  'Provider City': 'SACRAMENTO',
#  'Provider Id': 50017,
#  'Provider Name': 'MERCY GENERAL HOSPITAL',
#  'Provider State': 'CA',
#  'Provider Street Address': '4001 J ST',
#  'Provider Zip Code': 95819,
#  'Total Discharges': 27,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cac7')}
# {'Average Covered Charges': '$40062.46',
#  'Average Medicare Payments': '$6358.07',
#  'Average Total Payments': '$7449.80',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'CA - San Diego',
#  'Provider City': 'LA MESA',
#  'Provider Id': 50026,
#  'Provider Name': 'GROSSMONT HOSPITAL',
#  'Provider State': 'CA',
#  'Provider Street Address': '5555 GROSSMONT CENTER DRIVE BOX 58',
#  'Provider Zip Code': 91942,
#  'Total Discharges': 26,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cac8')}
# {'Average Covered Charges': '$53334.80',
#  'Average Medicare Payments': '$6213.19',
#  'Average Total Payments': '$8012.23',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'CA - Bakersfield',
#  'Provider City': 'BAKERSFIELD',
#  'Provider Id': 50036,
#  'Provider Name': 'BAKERSFIELD MEMORIAL HOSPITAL',
#  'Provider State': 'CA',
#  'Provider Street Address': '420 34TH ST BOX 1888',
#  'Provider Zip Code': 93301,
#  'Total Discharges': 21,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cac9')}
# {'Average Covered Charges': '$42446.30',
#  'Average Medicare Payments': '$5966.62',
#  'Average Total Payments': '$6967.73',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'CA - Chico',
#  'Provider City': 'CHICO',
#  'Provider Id': 50039,
#  'Provider Name': 'ENLOE MEDICAL CENTER',
#  'Provider State': 'CA',
#  'Provider Street Address': '1531 ESPLANADE',
#  'Provider Zip Code': 95926,
#  'Total Discharges': 56,
#  '_id': ObjectId('5ea5b7413b3975ff34d9caca')}
# {'Average Covered Charges': '$27027.93',
#  'Average Medicare Payments': '$6639.33',
#  'Average Total Payments': '$8333.86',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'CA - Los Angeles',
#  'Provider City': 'LANCASTER',
#  'Provider Id': 50056,
#  'Provider Name': 'ANTELOPE VALLEY HOSPITAL MED CENTER',
#  'Provider State': 'CA',
#  'Provider Street Address': '1600 W AVE J',
#  'Provider Zip Code': 93534,
#  'Total Discharges': 15,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cacb')}
# {'Average Covered Charges': '$30686.01',
#  'Average Medicare Payments': '$6247.48',
#  'Average Total Payments': '$7562.26',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'CA - Bakersfield',
#  'Provider City': 'VISALIA',
#  'Provider Id': 50057,
#  'Provider Name': 'KAWEAH DELTA MEDICAL CENTER',
#  'Provider State': 'CA',
#  'Provider Street Address': '400 W MINERAL KING AVE',
#  'Provider Zip Code': 93291,
#  'Total Discharges': 52,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cacc')}
# {'Average Covered Charges': '$65099.54',
#  'Average Medicare Payments': '$10056.00',
#  'Average Total Payments': '$11082.18',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'CA - Los Angeles',
#  'Provider City': 'GLENDALE',
#  'Provider Id': 50058,
#  'Provider Name': 'GLENDALE MEM HOSPITAL & HLTH CENTER',
#  'Provider State': 'CA',
#  'Provider Street Address': '1420 S CENTRAL AVE',
#  'Provider Zip Code': 91204,
#  'Total Discharges': 11,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cacd')}
# {'Average Covered Charges': '$35690.02',
#  'Average Medicare Payments': '$6347.10',
#  'Average Total Payments': '$7188.90',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'CA - Orange County',
#  'Provider City': 'ORANGE',
#  'Provider Id': 50069,
#  'Provider Name': 'ST JOSEPH HOSPITAL',
#  'Provider State': 'CA',
#  'Provider Street Address': '1100 WEST STEWART DR',
#  'Provider Zip Code': 92868,
#  'Total Discharges': 40,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cace')}
# {'Average Covered Charges': '$57187.30',
#  'Average Medicare Payments': '$7925.84',
#  'Average Total Payments': '$8791.69',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'CA - San Diego',
#  'Provider City': 'SAN DIEGO',
#  'Provider Id': 50077,
#  'Provider Name': 'SCRIPPS MERCY HOSPITAL',
#  'Provider State': 'CA',
#  'Provider Street Address': '4077 5TH AVE',
#  'Provider Zip Code': 92103,
#  'Total Discharges': 13,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cacf')}
# {'Average Covered Charges': '$72051.89',
#  'Average Medicare Payments': '$6393.35',
#  'Average Total Payments': '$8009.17',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'CA - Ventura',
#  'Provider City': 'OXNARD',
#  'Provider Id': 50082,
#  'Provider Name': 'ST JOHNS REGIONAL MEDICAL CENTER',
#  'Provider State': 'CA',
#  'Provider Street Address': '1600 N ROSE AVE',
#  'Provider Zip Code': 93030,
#  'Total Discharges': 28,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cad0')}
# {'Average Covered Charges': '$59184.74',
#  'Average Medicare Payments': '$7758.53',
#  'Average Total Payments': '$8628.40',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'CA - Stockton',
#  'Provider City': 'STOCKTON',
#  'Provider Id': 50084,
#  'Provider Name': 'ST JOSEPHS MED CENTER OF STOCKTON',
#  'Provider State': 'CA',
#  'Provider Street Address': '1800 N CALIFORNIA ST',
#  'Provider Zip Code': 95204,
#  'Total Discharges': 66,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cad1')}
# {'Average Covered Charges': '$41460.67',
#  'Average Medicare Payments': '$6580.29',
#  'Average Total Payments': '$7471.70',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'CA - Fresno',
#  'Provider City': 'FRESNO',
#  'Provider Id': 50093,
#  'Provider Name': 'SAINT AGNES MEDICAL CENTER',
#  'Provider State': 'CA',
#  'Provider Street Address': '1303 E HERNDON AVE',
#  'Provider Zip Code': 93710,
#  'Total Discharges': 34,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cad2')}
# {'Average Covered Charges': '$51983.85',
#  'Average Medicare Payments': '$6967.76',
#  'Average Total Payments': '$7992.35',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'CA - Santa Barbara',
#  'Provider City': 'SANTA MARIA',
#  'Provider Id': 50107,
#  'Provider Name': 'MARIAN MEDICAL CENTER',
#  'Provider State': 'CA',
#  'Provider Street Address': '1400 E CHURCH ST',
#  'Provider Zip Code': 93454,
#  'Total Discharges': 34,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cad3')}
# {'Average Covered Charges': '$60997.16',
#  'Average Medicare Payments': '$7905.65',
#  'Average Total Payments': '$8894.85',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'CA - Sacramento',
#  'Provider City': 'SACRAMENTO',
#  'Provider Id': 50108,
#  'Provider Name': 'SUTTER GENERAL HOSPITAL',
#  'Provider State': 'CA',
#  'Provider Street Address': '2801 L STREET',
#  'Provider Zip Code': 95816,
#  'Total Discharges': 67,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cad4')}
# {'Average Covered Charges': '$44775.91',
#  'Average Medicare Payments': '$5583.00',
#  'Average Total Payments': '$6992.33',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'CA - San Diego',
#  'Provider City': 'ESCONDIDO',
#  'Provider Id': 50115,
#  'Provider Name': 'PALOMAR MEDICAL CENTER',
#  'Provider State': 'CA',
#  'Provider Street Address': '555 E VALLEY PARKWAY',
#  'Provider Zip Code': 92025,
#  'Total Discharges': 12,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cad5')}
# {'Average Covered Charges': '$52977.92',
#  'Average Medicare Payments': '$6598.30',
#  'Average Total Payments': '$7548.76',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'CA - San Diego',
#  'Provider City': 'OCEANSIDE',
#  'Provider Id': 50128,
#  'Provider Name': 'TRI-CITY MEDICAL CENTER',
#  'Provider State': 'CA',
#  'Provider Street Address': '4002 VISTA WAY',
#  'Provider Zip Code': 92056,
#  'Total Discharges': 26,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cad6')}
# {'Average Covered Charges': '$45246.74',
#  'Average Medicare Payments': '$6946.70',
#  'Average Total Payments': '$7863.14',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'CA - Sacramento',
#  'Provider City': 'MARYSVILLE',
#  'Provider Id': 50133,
#  'Provider Name': 'RIDEOUT MEMORIAL HOSPITAL',
#  'Provider State': 'CA',
#  'Provider Street Address': '726 4TH ST',
#  'Provider Zip Code': 95901,
#  'Total Discharges': 27,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cad7')}
# {'Average Covered Charges': '$39046.81',
#  'Average Medicare Payments': '$5465.62',
#  'Average Total Payments': '$6710.81',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'CA - Orange County',
#  'Provider City': 'FULLERTON',
#  'Provider Id': 50168,
#  'Provider Name': 'ST JUDE MEDICAL CENTER',
#  'Provider State': 'CA',
#  'Provider Street Address': '101 E VALENCIA MESA DRIVE',
#  'Provider Zip Code': 92835,
#  'Total Discharges': 16,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cad8')}
# {'Average Covered Charges': '$82480.75',
#  'Average Medicare Payments': '$7773.50',
#  'Average Total Payments': '$8830.75',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'CA - Santa Rosa',
#  'Provider City': 'SANTA ROSA',
#  'Provider Id': 50174,
#  'Provider Name': 'SANTA ROSA MEMORIAL HOSPITAL',
#  'Provider State': 'CA',
#  'Provider Street Address': '1165 MONTGOMERY DR',
#  'Provider Zip Code': 95405,
#  'Total Discharges': 16,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cad9')}
# {'Average Covered Charges': '$57258.73',
#  'Average Medicare Payments': '$6888.26',
#  'Average Total Payments': '$7714.13',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'CA - Modesto',
#  'Provider City': 'TURLOCK',
#  'Provider Id': 50179,
#  'Provider Name': 'EMANUEL MEDICAL CENTER INC',
#  'Provider State': 'CA',
#  'Provider Street Address': '825 DELBON AVE',
#  'Provider Zip Code': 95382,
#  'Total Discharges': 15,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cada')}
# {'Average Covered Charges': '$51813.13',
#  'Average Medicare Payments': '$5585.21',
#  'Average Total Payments': '$8349.60',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'CA - Los Angeles',
#  'Provider City': 'LONG BEACH',
#  'Provider Id': 50485,
#  'Provider Name': 'LONG BEACH MEMORIAL MEDICAL CENTER',
#  'Provider State': 'CA',
#  'Provider Street Address': '2801 ATLANTIC AVE',
#  'Provider Zip Code': 90806,
#  'Total Discharges': 23,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cadb')}
# {'Average Covered Charges': '$85165.10',
#  'Average Medicare Payments': '$6776.50',
#  'Average Total Payments': '$12355.85',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'CA - Contra Costa County',
#  'Provider City': 'WALNUT CREEK',
#  'Provider Id': 50180,
#  'Provider Name': 'JOHN MUIR MEDICAL CENTER - WALNUT CREEK CAMPUS',
#  'Provider State': 'CA',
#  'Provider Street Address': '1601 YGNACIO VALLEY RD',
#  'Provider Zip Code': 94598,
#  'Total Discharges': 20,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cadc')}
# {'Average Covered Charges': '$94693.84',
#  'Average Medicare Payments': '$6084.89',
#  'Average Total Payments': '$8682.94',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'CA - San Mateo County',
#  'Provider City': 'REDWOOD CITY',
#  'Provider Id': 50197,
#  'Provider Name': 'SEQUOIA HOSPITAL',
#  'Provider State': 'CA',
#  'Provider Street Address': '170 ALAMEDA DE LAS PULGAS',
#  'Provider Zip Code': 94062,
#  'Total Discharges': 19,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cadd')}
# {'Average Covered Charges': '$55232.69',
#  'Average Medicare Payments': '$7410.23',
#  'Average Total Payments': '$8104.38',
#  'DRG Definition': '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC',
#  'Hospital Referral Region Description': 'CA - San Diego',
#  'Provider City': 'CHULA VISTA',
#  'Provider Id': 50222,
#  'Provider Name': 'SHARP CHULA VISTA MEDICAL CENTER',
#  'Provider State': 'CA',
#  'Provider Street Address': '751 MEDICAL CENTER COURT',
#  'Provider Zip Code': 91911,
#  'Total Discharges': 13,
#  '_id': ObjectId('5ea5b7413b3975ff34d9cade')}
# {'Average Covered Charges': '$29350.85',
#  'Average Medicare Payments': '$5386.02',
#  'Average Total Payments': '$6511.29',
# ...
# {'Average Covered Charges': '$12195.53',
#  'Average Medicare Payments': '$4356.40',
#  'Average Total Payments': '$5253.46',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'NC - Charlotte',
#  'Provider City': 'MATTHEWS',
#  'Provider Id': 340171,
#  'Provider Name': 'PRESBYTERIAN HOSPITAL MATTHEWS',
#  'Provider State': 'NC',
#  'Provider Street Address': '1500 MATTHEWS TWNSHP PRKWY BOX 3310',
#  'Provider Zip Code': 28106,
#  'Total Discharges': 15,
#  '_id': ObjectId('5ea5e2b331442f9cb6544dcf')}
# {'Average Covered Charges': '$20385.08',
#  'Average Medicare Payments': '$4461.12',
#  'Average Total Payments': '$5354.62',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'NC - Raleigh',
#  'Provider City': 'CARY',
#  'Provider Id': 340173,
#  'Provider Name': 'WAKEMED, CARY HOSPITAL',
#  'Provider State': 'NC',
#  'Provider Street Address': '1900 KILDARE FARM ROAD',
#  'Provider Zip Code': 27511,
#  'Total Discharges': 24,
#  '_id': ObjectId('5ea5e2b331442f9cb6544dd0')}
# {'Average Covered Charges': '$15473.68',
#  'Average Medicare Payments': '$4917.42',
#  'Average Total Payments': '$5746.47',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'ND - Fargo/Moorhead MN',
#  'Provider City': 'FARGO',
#  'Provider Id': 350011,
#  'Provider Name': 'SANFORD MEDICAL CENTER FARGO',
#  'Provider State': 'ND',
#  'Provider Street Address': '801 BROADWAY NORTH',
#  'Provider Zip Code': 58122,
#  'Total Discharges': 19,
#  '_id': ObjectId('5ea5e2b331442f9cb6544dd1')}
# {'Average Covered Charges': '$17589.48',
#  'Average Medicare Payments': '$8696.87',
#  'Average Total Payments': '$9513.36',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'OH - Cincinnati',
#  'Provider City': 'CINCINNATI',
#  'Provider Id': 360003,
#  'Provider Name': 'UNIVERSITY HOSPITAL, INC',
#  'Provider State': 'OH',
#  'Provider Street Address': '234 GOODMAN STREET',
#  'Provider Zip Code': 45267,
#  'Total Discharges': 33,
#  '_id': ObjectId('5ea5e2b331442f9cb6544dd2')}
# {'Average Covered Charges': '$18988.83',
#  'Average Medicare Payments': '$4979.12',
#  'Average Total Payments': '$5759.06',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'OH - Columbus',
#  'Provider City': 'COLUMBUS',
#  'Provider Id': 360006,
#  'Provider Name': 'RIVERSIDE METHODIST HOSPITAL',
#  'Provider State': 'OH',
#  'Provider Street Address': '3535 OLENTANGY RIVER RD',
#  'Provider Zip Code': 43214,
#  'Total Discharges': 62,
#  '_id': ObjectId('5ea5e2b331442f9cb6544dd3')}
# {'Average Covered Charges': '$13645.72',
#  'Average Medicare Payments': '$4395.88',
#  'Average Total Payments': '$7332.61',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'OH - Columbus',
#  'Provider City': 'PORTSMOUTH',
#  'Provider Id': 360008,
#  'Provider Name': 'SOUTHERN OHIO MEDICAL CENTER',
#  'Provider State': 'OH',
#  'Provider Street Address': '1805 27TH STREET',
#  'Provider Zip Code': 45662,
#  'Total Discharges': 18,
#  '_id': ObjectId('5ea5e2b331442f9cb6544dd4')}
# {'Average Covered Charges': '$14315.86',
#  'Average Medicare Payments': '$4797.31',
#  'Average Total Payments': '$5713.31',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'OH - Columbus',
#  'Provider City': 'WESTERVILLE',
#  'Provider Id': 360012,
#  'Provider Name': "MOUNT CARMEL ST ANN'S HOSPITAL",
#  'Provider State': 'OH',
#  'Provider Street Address': '500 SOUTH CLEVELAND AVENUE',
#  'Provider Zip Code': 43081,
#  'Total Discharges': 22,
#  '_id': ObjectId('5ea5e2b331442f9cb6544dd5')}
# {'Average Covered Charges': '$27768.81',
#  'Average Medicare Payments': '$5946.81',
#  'Average Total Payments': '$6861.36',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'OH - Columbus',
#  'Provider City': 'COLUMBUS',
#  'Provider Id': 360017,
#  'Provider Name': 'GRANT MEDICAL CENTER',
#  'Provider State': 'OH',
#  'Provider Street Address': '111 SOUTH GRANT AVENUE',
#  'Provider Zip Code': 43215,
#  'Total Discharges': 11,
#  '_id': ObjectId('5ea5e2b331442f9cb6544dd6')}
# {'Average Covered Charges': '$21179.27',
#  'Average Medicare Payments': '$5279.81',
#  'Average Total Payments': '$6197.65',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'OH - Akron',
#  'Provider City': 'AKRON',
#  'Provider Id': 360020,
#  'Provider Name': 'SUMMA HEALTH SYSTEMS HOSPITALS',
#  'Provider State': 'OH',
#  'Provider Street Address': '525 EAST MARKET STREET',
#  'Provider Zip Code': 44309,
#  'Total Discharges': 66,
#  '_id': ObjectId('5ea5e2b331442f9cb6544dd7')}
# {'Average Covered Charges': '$12146.28',
#  'Average Medicare Payments': '$4791.33',
#  'Average Total Payments': '$5509.58',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'OH - Cleveland',
#  'Provider City': 'SANDUSKY',
#  'Provider Id': 360025,
#  'Provider Name': 'FIRELANDS REGIONAL MEDICAL CENTER',
#  'Provider State': 'OH',
#  'Provider Street Address': '1111 HAYES AVENUE',
#  'Provider Zip Code': 44870,
#  'Total Discharges': 39,
#  '_id': ObjectId('5ea5e2b331442f9cb6544dd8')}
# {'Average Covered Charges': '$16001.31',
#  'Average Medicare Payments': '$4826.48',
#  'Average Total Payments': '$6043.74',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'OH - Akron',
#  'Provider City': 'AKRON',
#  'Provider Id': 360027,
#  'Provider Name': 'AKRON GENERAL MEDICAL CENTER',
#  'Provider State': 'OH',
#  'Provider Street Address': '400 WABASH AVENUE',
#  'Provider Zip Code': 44307,
#  'Total Discharges': 35,
#  '_id': ObjectId('5ea5e2b331442f9cb6544dd9')}
# {'Average Covered Charges': '$8976.64',
#  'Average Medicare Payments': '$4838.97',
#  'Average Total Payments': '$5725.47',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'OH - Columbus',
#  'Provider City': 'COLUMBUS',
#  'Provider Id': 360035,
#  'Provider Name': 'MOUNT CARMEL HEALTH',
#  'Provider State': 'OH',
#  'Provider Street Address': '793 WEST STATE STREET',
#  'Provider Zip Code': 43222,
#  'Total Discharges': 34,
#  '_id': ObjectId('5ea5e2b331442f9cb6544dda')}
# {'Average Covered Charges': '$11931.16',
#  'Average Medicare Payments': '$4585.45',
#  'Average Total Payments': '$6213.61',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'OH - Columbus',
#  'Provider City': 'ZANESVILLE',
#  'Provider Id': 360039,
#  'Provider Name': 'GENESIS HEALTHCARE SYSTEM',
#  'Provider State': 'OH',
#  'Provider Street Address': '2951 MAPLE AVENUE',
#  'Provider Zip Code': 43701,
#  'Total Discharges': 31,
#  '_id': ObjectId('5ea5e2b331442f9cb6544ddb')}
# {'Average Covered Charges': '$10505.07',
#  'Average Medicare Payments': '$4129.42',
#  'Average Total Payments': '$4935.71',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'OH - Cleveland',
#  'Provider City': 'PARMA',
#  'Provider Id': 360041,
#  'Provider Name': 'PARMA COMMUNITY GENERAL HOSPITAL',
#  'Provider State': 'OH',
#  'Provider Street Address': '7007 POWERS BOULEVARD',
#  'Provider Zip Code': 44129,
#  'Total Discharges': 14,
#  '_id': ObjectId('5ea5e2b331442f9cb6544ddc')}
# {'Average Covered Charges': '$12898.71',
#  'Average Medicare Payments': '$6631.61',
#  'Average Total Payments': '$7581.95',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'OH - Toledo',
#  'Provider City': 'TOLEDO',
#  'Provider Id': 360048,
#  'Provider Name': 'UNIVERSITY OF TOLEDO MEDICAL CENTER',
#  'Provider State': 'OH',
#  'Provider Street Address': '3000 ARLINGTON AVENUE',
#  'Provider Zip Code': 43699,
#  'Total Discharges': 21,
#  '_id': ObjectId('5ea5e2b331442f9cb6544ddd')}
# {'Average Covered Charges': '$37908.81',
#  'Average Medicare Payments': '$5530.25',
#  'Average Total Payments': '$6355.92',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'OH - Dayton',
#  'Provider City': 'DAYTON',
#  'Provider Id': 360051,
#  'Provider Name': 'MIAMI VALLEY HOSPITAL',
#  'Provider State': 'OH',
#  'Provider Street Address': 'ONE WYOMING STREET',
#  'Provider Zip Code': 45409,
#  'Total Discharges': 27,
#  '_id': ObjectId('5ea5e2b331442f9cb6544dde')}
# {'Average Covered Charges': '$28132.88',
#  'Average Medicare Payments': '$5051.56',
#  'Average Total Payments': '$6041.95',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'OH - Dayton',
#  'Provider City': 'DAYTON',
#  'Provider Id': 360052,
#  'Provider Name': 'GOOD SAMARITAN HOSPITAL',
#  'Provider State': 'OH',
#  'Provider Street Address': '2222 PHILADELPHIA DRIVE',
#  'Provider Zip Code': 45406,
#  'Total Discharges': 71,
#  '_id': ObjectId('5ea5e2b331442f9cb6544ddf')}
# {'Average Covered Charges': '$19626.73',
#  'Average Medicare Payments': '$4017.06',
#  'Average Total Payments': '$4845.06',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'OH - Youngstown',
#  'Provider City': 'WARREN',
#  'Provider Id': 360055,
#  'Provider Name': 'TRUMBULL MEMORIAL HOSPITAL',
#  'Provider State': 'OH',
#  'Provider Street Address': '1350 EAST MARKET STREET',
#  'Provider Zip Code': 44482,
#  'Total Discharges': 15,
#  '_id': ObjectId('5ea5e2b331442f9cb6544de0')}
# {'Average Covered Charges': '$14396.73',
#  'Average Medicare Payments': '$4178.40',
#  'Average Total Payments': '$5079.73',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'OH - Cincinnati',
#  'Provider City': 'FAIRFIELD',
#  'Provider Id': 360056,
#  'Provider Name': 'MERCY HOSPITAL FAIRFIELD',
#  'Provider State': 'OH',
#  'Provider Street Address': '3000 MACK ROAD',
#  'Provider Zip Code': 45014,
#  'Total Discharges': 15,
#  '_id': ObjectId('5ea5e2b331442f9cb6544de1')}
# {'Average Covered Charges': '$9056.38',
#  'Average Medicare Payments': '$7358.92',
#  'Average Total Payments': '$8227.23',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'OH - Cleveland',
#  'Provider City': 'CLEVELAND',
#  'Provider Id': 360059,
#  'Provider Name': 'METRO HEALTH MEDICAL CENTER',
#  'Provider State': 'OH',
#  'Provider Street Address': '2500 METROHEALTH DRIVE',
#  'Provider Zip Code': 44109,
#  'Total Discharges': 13,
#  '_id': ObjectId('5ea5e2b331442f9cb6544de2')}
# {'Average Covered Charges': '$13687.52',
#  'Average Medicare Payments': '$4670.05',
#  'Average Total Payments': '$5526.92',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'OH - Youngstown',
#  'Provider City': 'YOUNGSTOWN',
#  'Provider Id': 360064,
#  'Provider Name': 'ST ELIZABETH HEALTH CENTER',
#  'Provider State': 'OH',
#  'Provider Street Address': '1044 BELMONT AVENUE',
#  'Provider Zip Code': 44501,
#  'Total Discharges': 55,
#  '_id': ObjectId('5ea5e2b331442f9cb6544de3')}
# {'Average Covered Charges': '$13475.06',
#  'Average Medicare Payments': '$4377.93',
#  'Average Total Payments': '$5270.73',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'OH - Cleveland',
#  'Provider City': 'NORWALK',
#  'Provider Id': 360065,
#  'Provider Name': 'FISHER-TITUS HOSPITAL',
#  'Provider State': 'OH',
#  'Provider Street Address': '272 BENEDICT AVENUE',
#  'Provider Zip Code': 44857,
#  'Total Discharges': 15,
#  '_id': ObjectId('5ea5e2b331442f9cb6544de4')}
# {'Average Covered Charges': '$16055.40',
#  'Average Medicare Payments': '$4522.17',
#  'Average Total Payments': '$5261.48',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'OH - Dayton',
#  'Provider City': 'LIMA',
#  'Provider Id': 360066,
#  'Provider Name': "ST RITA'S MEDICAL CENTER",
#  'Provider State': 'OH',
#  'Provider Street Address': '730 WEST MARKET STREET',
#  'Provider Zip Code': 45801,
#  'Total Discharges': 35,
#  '_id': ObjectId('5ea5e2b331442f9cb6544de5')}
# {'Average Covered Charges': '$30092.21',
#  'Average Medicare Payments': '$5167.71',
#  'Average Total Payments': '$6128.85',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'OH - Toledo',
#  'Provider City': 'TOLEDO',
#  'Provider Id': 360068,
#  'Provider Name': 'TOLEDO HOSPITAL THE',
#  'Provider State': 'OH',
#  'Provider Street Address': '2142 NORTH COVE BOULEVARD',
#  'Provider Zip Code': 43606,
#  'Total Discharges': 14,
#  '_id': ObjectId('5ea5e2b331442f9cb6544de6')}
# {'Average Covered Charges': '$6751.95',
#  'Average Medicare Payments': '$4202.47',
#  'Average Total Payments': '$5008.00',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'OH - Canton',
#  'Provider City': 'CANTON',
#  'Provider Id': 360070,
#  'Provider Name': 'MERCY MEDICAL CENTER',
#  'Provider State': 'OH',
#  'Provider Street Address': '1320 MERCY DRIVE NW',
#  'Provider Zip Code': 44708,
#  'Total Discharges': 21,
#  '_id': ObjectId('5ea5e2b331442f9cb6544de7')}
# {'Average Covered Charges': '$8405.38',
#  'Average Medicare Payments': '$4183.88',
#  'Average Total Payments': '$5125.44',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'OH - Columbus',
#  'Provider City': 'LANCASTER',
#  'Provider Id': 360072,
#  'Provider Name': 'FAIRFIELD MEDICAL CENTER',
#  'Provider State': 'OH',
#  'Provider Street Address': '401 NORTH EWING STREET',
#  'Provider Zip Code': 43130,
#  'Total Discharges': 18,
#  '_id': ObjectId('5ea5e2b331442f9cb6544de8')}
# {'Average Covered Charges': '$17970.52',
#  'Average Medicare Payments': '$4594.04',
#  'Average Total Payments': '$5534.68',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'OH - Cleveland',
#  'Provider City': 'CLEVELAND',
#  'Provider Id': 360077,
#  'Provider Name': 'FAIRVIEW HOSPITAL',
#  'Provider State': 'OH',
#  'Provider Street Address': '18101 LORAIN AVENUE',
#  'Provider Zip Code': 44111,
#  'Total Discharges': 25,
#  '_id': ObjectId('5ea5e2b331442f9cb6544de9')}
# {'Average Covered Charges': '$9904.36',
#  'Average Medicare Payments': '$3262.81',
#  'Average Total Payments': '$4622.63',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'OH - Akron',
#  'Provider City': 'RAVENNA',
#  'Provider Id': 360078,
#  'Provider Name': 'ROBINSON MEMORIAL HOSPITAL',
#  'Provider State': 'OH',
#  'Provider Street Address': '6847 N CHESTNUT',
#  'Provider Zip Code': 44266,
#  'Total Discharges': 11,
#  '_id': ObjectId('5ea5e2b331442f9cb6544dea')}
# {'Average Covered Charges': '$24490.64',
#  'Average Medicare Payments': '$5126.64',
#  'Average Total Payments': '$6245.84',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'OH - Kettering',
#  'Provider City': 'KETTERING',
#  'Provider Id': 360079,
#  'Provider Name': 'KETTERING MEDICAL CENTER',
#  'Provider State': 'OH',
#  'Provider Street Address': '3535 SOUTHERN BOULEVARD',
#  'Provider Zip Code': 45429,
#  'Total Discharges': 25,
#  '_id': ObjectId('5ea5e2b331442f9cb6544deb')}
# {'Average Covered Charges': '$11696.27',
#  'Average Medicare Payments': '$4075.05',
#  'Average Total Payments': '$4946.61',
#  'DRG Definition': '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
#  'Hospital Referral Region Description': 'OH - Cleveland',
#  'Provider City': 'EUCLID',
#  'Provider Id': 360082,
#  'Provider Name': 'EUCLID HOSPITAL',
#  'Provider State': 'OH',
#  'Provider Street Address': '18901 LAKE SHORE BOULEVARD',
#  'Provider Zip Code': 44119,
#  'Total Discharges': 18,
#  '_id': ObjectId('5ea5e2b331442f9cb6544dec')}

# %%
df = pd.DataFrame(list(collection_dap.find()))

# %%
df
# Out:
#                            _id  \
# 0     5ea5b7403b3975ff34d9ca84
# 1     5ea5b7403b3975ff34d9ca85
# 2     5ea5b7403b3975ff34d9ca86
# 3     5ea5b7403b3975ff34d9ca87
# 4     5ea5b7403b3975ff34d9ca88
# ...                        ...
# 1977  5ea5b7423b3975ff34d9d23d
# 1978  5ea5b7423b3975ff34d9d23e
# 1979  5ea5b7423b3975ff34d9d23f
# 1980  5ea5b7423b3975ff34d9d240
# 1981  5ea5b7423b3975ff34d9d241
#
#                                          DRG Definition  Provider Id  \
# 0              039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10001
# 1              039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10005
# 2              039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10006
# 3              039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10011
# 4              039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10016
# ...                                                 ...          ...
# 1977  057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/...       360072
# 1978  057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/...       360077
# 1979  057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/...       360078
# 1980  057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/...       360079
# 1981  057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/...       360082
#
#                          Provider Name     Provider Street Address  \
# 0     SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE
# 1        MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH
# 2       ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET
# 3                    ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE
# 4        SHELBY BAPTIST MEDICAL CENTER     1000 FIRST STREET NORTH
# ...                                ...                         ...
# 1977          FAIRFIELD MEDICAL CENTER      401 NORTH EWING STREET
# 1978                 FAIRVIEW HOSPITAL         18101 LORAIN AVENUE
# 1979        ROBINSON MEMORIAL HOSPITAL             6847 N CHESTNUT
# 1980          KETTERING MEDICAL CENTER     3535 SOUTHERN BOULEVARD
# 1981                   EUCLID HOSPITAL  18901 LAKE SHORE BOULEVARD
#
#      Provider City Provider State  Provider Zip Code  \
# 0           DOTHAN             AL              36301
# 1             BOAZ             AL              35957
# 2         FLORENCE             AL              35631
# 3       BIRMINGHAM             AL              35235
# 4        ALABASTER             AL              35007
# ...            ...            ...                ...
# 1977     LANCASTER             OH              43130
# 1978     CLEVELAND             OH              44111
# 1979       RAVENNA             OH              44266
# 1980     KETTERING             OH              45429
# 1981        EUCLID             OH              44119
#
#      Hospital Referral Region Description  Total Discharges  \
# 0                             AL - Dothan                91
# 1                         AL - Birmingham                14
# 2                         AL - Birmingham                24
# 3                         AL - Birmingham                25
# 4                         AL - Birmingham                18
# ...                                   ...               ...
# 1977                        OH - Columbus                18
# 1978                       OH - Cleveland                25
# 1979                           OH - Akron                11
# 1980                       OH - Kettering                25
# 1981                       OH - Cleveland                18
#
#      Average Covered Charges Average Total Payments Average Medicare Payments
# 0                  $32963.07               $5777.24                  $4763.73
# 1                  $15131.85               $5787.57                  $4976.71
# 2                  $37560.37               $5434.95                  $4453.79
# 3                  $13998.28               $5417.56                  $4129.16
# 4                  $31633.27               $5658.33                  $4851.44
# ...                      ...                    ...                       ...
# 1977                $8405.38               $5125.44                  $4183.88
# 1978               $17970.52               $5534.68                  $4594.04
# 1979                $9904.36               $4622.63                  $3262.81
# 1980               $24490.64               $6245.84                  $5126.64
# 1981               $11696.27               $4946.61                  $4075.05
#
# [1982 rows x 13 columns]

# %%
import numpy as np 
import pandas as pd 
#import osdata.isnull().sum()

import matplotlib.pyplot as pl
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df.head()
# Out:
#                         _id                            DRG Definition  \
# 0  5ea5b7403b3975ff34d9ca84  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 1  5ea5b7403b3975ff34d9ca85  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 2  5ea5b7403b3975ff34d9ca86  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 3  5ea5b7403b3975ff34d9ca87  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 4  5ea5b7403b3975ff34d9ca88  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
#
#    Provider Id                     Provider Name     Provider Street Address  \
# 0        10001  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE
# 1        10005     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH
# 2        10006    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET
# 3        10011                 ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE
# 4        10016     SHELBY BAPTIST MEDICAL CENTER     1000 FIRST STREET NORTH
#
#   Provider City Provider State  Provider Zip Code  \
# 0        DOTHAN             AL              36301
# 1          BOAZ             AL              35957
# 2      FLORENCE             AL              35631
# 3    BIRMINGHAM             AL              35235
# 4     ALABASTER             AL              35007
#
#   Hospital Referral Region Description  Total Discharges  \
# 0                          AL - Dothan                91
# 1                      AL - Birmingham                14
# 2                      AL - Birmingham                24
# 3                      AL - Birmingham                25
# 4                      AL - Birmingham                18
#
#   Average Covered Charges Average Total Payments Average Medicare Payments
# 0               $32963.07               $5777.24                  $4763.73
# 1               $15131.85               $5787.57                  $4976.71
# 2               $37560.37               $5434.95                  $4453.79
# 3               $13998.28               $5417.56                  $4129.16
# 4               $31633.27               $5658.33                  $4851.44

# %%
Hcost = df.drop(['_id'],axis=1)

# %%
Hcost
# Out:
#                                          DRG Definition  Provider Id  \
# 0              039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10001
# 1              039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10005
# 2              039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10006
# 3              039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10011
# 4              039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10016
# ...                                                 ...          ...
# 1977  057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/...       360072
# 1978  057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/...       360077
# 1979  057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/...       360078
# 1980  057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/...       360079
# 1981  057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/...       360082
#
#                          Provider Name     Provider Street Address  \
# 0     SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE
# 1        MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH
# 2       ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET
# 3                    ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE
# 4        SHELBY BAPTIST MEDICAL CENTER     1000 FIRST STREET NORTH
# ...                                ...                         ...
# 1977          FAIRFIELD MEDICAL CENTER      401 NORTH EWING STREET
# 1978                 FAIRVIEW HOSPITAL         18101 LORAIN AVENUE
# 1979        ROBINSON MEMORIAL HOSPITAL             6847 N CHESTNUT
# 1980          KETTERING MEDICAL CENTER     3535 SOUTHERN BOULEVARD
# 1981                   EUCLID HOSPITAL  18901 LAKE SHORE BOULEVARD
#
#      Provider City Provider State  Provider Zip Code  \
# 0           DOTHAN             AL              36301
# 1             BOAZ             AL              35957
# 2         FLORENCE             AL              35631
# 3       BIRMINGHAM             AL              35235
# 4        ALABASTER             AL              35007
# ...            ...            ...                ...
# 1977     LANCASTER             OH              43130
# 1978     CLEVELAND             OH              44111
# 1979       RAVENNA             OH              44266
# 1980     KETTERING             OH              45429
# 1981        EUCLID             OH              44119
#
#      Hospital Referral Region Description  Total Discharges  \
# 0                             AL - Dothan                91
# 1                         AL - Birmingham                14
# 2                         AL - Birmingham                24
# 3                         AL - Birmingham                25
# 4                         AL - Birmingham                18
# ...                                   ...               ...
# 1977                        OH - Columbus                18
# 1978                       OH - Cleveland                25
# 1979                           OH - Akron                11
# 1980                       OH - Kettering                25
# 1981                       OH - Cleveland                18
#
#      Average Covered Charges Average Total Payments Average Medicare Payments
# 0                  $32963.07               $5777.24                  $4763.73
# 1                  $15131.85               $5787.57                  $4976.71
# 2                  $37560.37               $5434.95                  $4453.79
# 3                  $13998.28               $5417.56                  $4129.16
# 4                  $31633.27               $5658.33                  $4851.44
# ...                      ...                    ...                       ...
# 1977                $8405.38               $5125.44                  $4183.88
# 1978               $17970.52               $5534.68                  $4594.04
# 1979                $9904.36               $4622.63                  $3262.81
# 1980               $24490.64               $6245.84                  $5126.64
# 1981               $11696.27               $4946.61                  $4075.05
#
# [1982 rows x 12 columns]

# %%
Hcost.isnull().sum()
# Out:
# DRG Definition                          0
# Provider Id                             0
# Provider Name                           0
# Provider Street Address                 0
# Provider City                           0
# Provider State                          0
# Provider Zip Code                       0
# Hospital Referral Region Description    0
# Total Discharges                        0
# Average Covered Charges                 0
# Average Total Payments                  0
# Average Medicare Payments               0
# dtype: int64

# %%
Hcost.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1982 entries, 0 to 1981
# Data columns (total 12 columns):
# DRG Definition                          1982 non-null object
# Provider Id                             1982 non-null int64
# Provider Name                           1982 non-null object
# Provider Street Address                 1982 non-null object
# Provider City                           1982 non-null object
# Provider State                          1982 non-null object
# Provider Zip Code                       1982 non-null int64
# Hospital Referral Region Description    1982 non-null object
# Total Discharges                        1982 non-null int64
# Average Covered Charges                 1982 non-null object
# Average Total Payments                  1982 non-null object
# Average Medicare Payments               1982 non-null object
# dtypes: int64(3), object(9)
# memory usage: 185.9+ KB

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import psycopg2
from  psycopg2.extensions import connection as DB_CON
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
def get_dbCon():
        try:
            SQLconnect=psycopg2.connect(host='localhost',port=5432,database="db_project",user='postgres',password="123456789")
            return SQLconnect
        except Exception as Ex:
            print('Db connection occurred-',EX)

# %%
table_name ='drug_exp'
col_name = list(Hcost.head(0))

# %%
from sqlalchemy import create_engine
import pandas as pd
#import mplfinance as mpf
import matplotlib.pyplot as plt
import numpy

# %%
engine = create_engine('postgresql://postgres:123456789@localhost:5432/db_project')

# %%
Hcost.to_sql('drug_exp', engine,index=False)

# %%
import pandas as pd
import pandas.io.sql as sqlio
import psycopg2

sql = "SELECT * FROM public.drug_exp"
try:
    dbConnection = psycopg2.connect(
        user = "postgres",
        password = "123456789",
        host = "localhost",
        port = "5432",
        database = "db_project")
    sql_df = sqlio.read_sql_query(sql, dbConnection)
except (Exception , psycopg2.Error) as dbError :
    print ("Error:", dbError)
finally:
    if(dbConnection): dbConnection.close()

# %%
sql_df
# Out:
#                                          DRG Definition  Provider Id  \
# 0              039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10001
# 1              039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10005
# 2              039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10006
# 3              039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10011
# 4              039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10016
# ...                                                 ...          ...
# 1977  057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/...       360072
# 1978  057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/...       360077
# 1979  057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/...       360078
# 1980  057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/...       360079
# 1981  057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/...       360082
#
#                          Provider Name     Provider Street Address  \
# 0     SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE
# 1        MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH
# 2       ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET
# 3                    ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE
# 4        SHELBY BAPTIST MEDICAL CENTER     1000 FIRST STREET NORTH
# ...                                ...                         ...
# 1977          FAIRFIELD MEDICAL CENTER      401 NORTH EWING STREET
# 1978                 FAIRVIEW HOSPITAL         18101 LORAIN AVENUE
# 1979        ROBINSON MEMORIAL HOSPITAL             6847 N CHESTNUT
# 1980          KETTERING MEDICAL CENTER     3535 SOUTHERN BOULEVARD
# 1981                   EUCLID HOSPITAL  18901 LAKE SHORE BOULEVARD
#
#      Provider City Provider State  Provider Zip Code  \
# 0           DOTHAN             AL              36301
# 1             BOAZ             AL              35957
# 2         FLORENCE             AL              35631
# 3       BIRMINGHAM             AL              35235
# 4        ALABASTER             AL              35007
# ...            ...            ...                ...
# 1977     LANCASTER             OH              43130
# 1978     CLEVELAND             OH              44111
# 1979       RAVENNA             OH              44266
# 1980     KETTERING             OH              45429
# 1981        EUCLID             OH              44119
#
#      Hospital Referral Region Description  Total Discharges  \
# 0                             AL - Dothan                91
# 1                         AL - Birmingham                14
# 2                         AL - Birmingham                24
# 3                         AL - Birmingham                25
# 4                         AL - Birmingham                18
# ...                                   ...               ...
# 1977                        OH - Columbus                18
# 1978                       OH - Cleveland                25
# 1979                           OH - Akron                11
# 1980                       OH - Kettering                25
# 1981                       OH - Cleveland                18
#
#      Average Covered Charges Average Total Payments Average Medicare Payments
# 0                  $32963.07               $5777.24                  $4763.73
# 1                  $15131.85               $5787.57                  $4976.71
# 2                  $37560.37               $5434.95                  $4453.79
# 3                  $13998.28               $5417.56                  $4129.16
# 4                  $31633.27               $5658.33                  $4851.44
# ...                      ...                    ...                       ...
# 1977                $8405.38               $5125.44                  $4183.88
# 1978               $17970.52               $5534.68                  $4594.04
# 1979                $9904.36               $4622.63                  $3262.81
# 1980               $24490.64               $6245.84                  $5126.64
# 1981               $11696.27               $4946.61                  $4075.05
#
# [1982 rows x 12 columns]

# %%
#EDA
import pandas as pd
import numpy as np
import seaborn as sns
import pdb
import os

# %matplotlib inline
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
sql_df.describe()
# Out:
#          Provider Id  Provider Zip Code  Total Discharges
# count    1982.000000        1982.000000       1982.000000
# mean   225932.300706       45428.042886         28.793643
# std    136130.977997       27433.942636         20.308556
# min     10001.000000        1040.000000         11.000000
# 25%    100256.000000       23676.250000         15.000000
# 50%    220056.000000       43170.000000         22.000000
# 75%    330202.750000       65201.000000         35.000000
# max    670025.000000       99519.000000        224.000000

# %%
sql_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1982 entries, 0 to 1981
# Data columns (total 12 columns):
# DRG Definition                          1982 non-null object
# Provider Id                             1982 non-null int64
# Provider Name                           1982 non-null object
# Provider Street Address                 1982 non-null object
# Provider City                           1982 non-null object
# Provider State                          1982 non-null object
# Provider Zip Code                       1982 non-null int64
# Hospital Referral Region Description    1982 non-null object
# Total Discharges                        1982 non-null int64
# Average Covered Charges                 1982 non-null object
# Average Total Payments                  1982 non-null object
# Average Medicare Payments               1982 non-null object
# dtypes: int64(3), object(9)
# memory usage: 185.9+ KB

# %%
sql_df['DRG Definition'].unique().shape
sql_df['Provider Id'].unique().shape
sql_df['Provider City'].unique().shape
# Out:
# (922,)

# %%
sql_df.columns = [column.strip() for column in sql_df.columns]

# %%
sql_df.columns
# Out:
# Index(['DRG Definition', 'Provider Id', 'Provider Name',
#        'Provider Street Address', 'Provider City', 'Provider State',
#        'Provider Zip Code', 'Hospital Referral Region Description',
#        'Total Discharges', 'Average Covered Charges', 'Average Total Payments',
#        'Average Medicare Payments'],
#       dtype='object')

# %%
for column in ['Average Covered Charges', 'Average Total Payments', 'Average Medicare Payments']:
    sql_df[column] = sql_df[column].map(lambda x: x[1:])
    sql_df[column] = pd.to_numeric(sql_df[column])

# %%
sql_df.head()
# Out:
#                              DRG Definition  Provider Id  \
# 0  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10001
# 1  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10005
# 2  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10006
# 3  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10011
# 4  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10016
#
#                       Provider Name     Provider Street Address Provider City  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE        DOTHAN
# 1     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH          BOAZ
# 2    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET      FLORENCE
# 3                 ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE    BIRMINGHAM
# 4     SHELBY BAPTIST MEDICAL CENTER     1000 FIRST STREET NORTH     ALABASTER
#
#   Provider State  Provider Zip Code Hospital Referral Region Description  \
# 0             AL              36301                          AL - Dothan
# 1             AL              35957                      AL - Birmingham
# 2             AL              35631                      AL - Birmingham
# 3             AL              35235                      AL - Birmingham
# 4             AL              35007                      AL - Birmingham
#
#    Total Discharges  Average Covered Charges  Average Total Payments  \
# 0                91                  2963.07                 5777.24
# 1                14                  5131.85                 5787.57
# 2                24                  7560.37                 5434.95
# 3                25                  3998.28                 5417.56
# 4                18                  1633.27                 5658.33
#
#    Average Medicare Payments
# 0                    4763.73
# 1                    4976.71
# 2                    4453.79
# 3                    4129.16
# 4                    4851.44

# %%
agg_columns = ['mean', 'median', 'var', 'std', 'count', 'min', 'max']
groupby_drg = sql_df[['DRG Definition', 'Average Total Payments']].groupby(by='DRG Definition').agg(agg_columns)
groupby_drg.columns = [header + '-' + agg_column 
                       for header, agg_column in zip(groupby_drg.columns.get_level_values(0), agg_columns)]
groupby_drg.columns = groupby_drg.columns.get_level_values(0)

# %%
groupby_drg.reset_index(inplace=True)
groupby_drg['Average Total Payments-range'] = groupby_drg['Average Total Payments-max'] - groupby_drg['Average Total Payments-min']
groupby_drg.head()
# Out:
#                                       DRG Definition  \
# 0           039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 1  057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/...
# 2                           069 - TRANSIENT ISCHEMIA
#
#    Average Total Payments-mean  Average Total Payments-median  \
# 0                  6960.534004                       6582.890
# 1                  6857.019812                       6217.965
# 2                  4277.310000                       4277.310
#
#    Average Total Payments-var  Average Total Payments-std  \
# 0                2.184111e+06                 1477.873952
# 1                4.708270e+06                 2169.854784
# 2                         NaN                         NaN
#
#    Average Total Payments-count  Average Total Payments-min  \
# 0                          1079                     4968.00
# 1                           902                     4194.09
# 2                             1                     4277.31
#
#    Average Total Payments-max  Average Total Payments-range
# 0                    18420.56                      13452.56
# 1                    25519.43                      21325.34
# 2                     4277.31                          0.00

# %%
def plt_setup(_plt):
    _plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off')

# %%
#A few treatments (DRG Definitions) are noticeably more costly than others
sns.barplot(x='DRG Definition', y='Average Total Payments-mean', 
            data=groupby_drg.sort_values('Average Total Payments-mean'))
plt_setup(plt)
plt.title('Mean Average Total Payments by DRG', fontsize=16)
plt.ylabel('Mean of Average Total Payments', fontsize=16)
# Out:
# Text(0, 0.5, 'Mean of Average Total Payments')

# %%
#There are cheaper options for the most expensive DRG Definitions
plt.figure(figsize=(20,5))
sns.barplot(x='DRG Definition', y='Average Total Payments-var', 
            data=groupby_drg.sort_values('Average Total Payments-mean'))
plt_setup(plt)
plt.title('Mean Average Total Payments Variance by DRG', fontsize=16)
plt.ylabel('Mean of Average Total Payments Variance', fontsize=16)
# Out:
# Text(0, 0.5, 'Mean of Average Total Payments Variance')

# %%
#Most expensive DRGs a​lso have the highest range in costs
plt.figure(figsize=(20,5))
sns.barplot(x='DRG Definition', y='Average Total Payments-range', 
            data=groupby_drg.sort_values('Average Total Payments-var'))
plt_setup(plt)
plt.title('Mean Average Total Payments Range by DRG', fontsize=16)
plt.ylabel('Mean of Average Total Payments Range', fontsize=16)
# Out:
# Text(0, 0.5, 'Mean of Average Total Payments Range')

# %%
query = '''
SELECT "DRG Definition", "Provider State" AS providerState, t.maxAvgPaymentPerDRG
FROM drug_exp hc
INNER JOIN (
    SELECT "DRG Definition" AS drg, MAX("Average Total Payments") AS maxAvgPaymentPerDRG
    FROM drug_exp
    GROUP BY "DRG Definition"
) t
ON hc."DRG Definition" = t.drg AND hc."Average Total Payments" = t.maxAvgPaymentPerDRG
ORDER BY providerState ASC
'''

cursor = engine.execute(query)
results = [record for record in cursor]
#engine.close()

# %%
results
# Out:
# [('069 - TRANSIENT ISCHEMIA', 'AL', '$4277.31'),
#  ('057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC', 'KY', '$9970.45'),
#  ('039 - EXTRACRANIAL PROCEDURES W/O CC/MCC', 'WY', '$9931.12')]

# %%
_df = pd.DataFrame(results, columns=['DRG', 'ProviderState', 'Payment'])

# %%
_df
# Out:
#                                                  DRG ProviderState   Payment
# 0                           069 - TRANSIENT ISCHEMIA            AL  $4277.31
# 1  057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/...            KY  $9970.45
# 2           039 - EXTRACRANIAL PROCEDURES W/O CC/MCC            WY  $9931.12

# %%
ranking_by_drg = dict()
for drg in df['DRG Definition'].unique():

    query = """
        SELECT "Provider State" as providerState, "Average Total Payments" as avg_asc
        FROM drug_exp
        WHERE "DRG Definition" = '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC' 
        GROUP BY "Provider State", "Average Total Payments"
        ORDER BY avg_asc
    """
    
    cursor = engine.execute(query)
    ranking_by_drg[drg] = [record[0] for record in cursor]

# %%
ranking_by_drg
# Out:
# {'039 - EXTRACRANIAL PROCEDURES W/O CC/MCC': ['AZ',
#   'MA',
#   'TX',
#   'MS',
#   'MI',
#   'PA',
#   'NY',
#   'WI',
#   'IL',
#   'MA',
#   'MD',
#   'IL',
#   'LA',
#   'DC',
#   'VA',
#   'MD',
#   'NY',
#   'CA',
#   'CA',
#   'MD',
#   'HI',
#   'AZ',
#   'NY',
#   'CA',
#   'NY',
#   'NY',
#   'MD',
#   'MA',
#   'NY',
#   'CA',
#   'CA',
#   'NY',
#   'CA',
#   'NY',
#   'MD',
#   'CA',
#   'CA',
#   'WA',
#   'MD',
#   'NY',
#   'MN',
#   'NY',
#   'CA',
#   'MD',
#   'IL',
#   'IL',
#   'AL',
#   'AL',
#   'MO',
#   'IN',
#   'WV',
#   'TN',
#   'PA',
#   'PA',
#   'TN',
#   'TN',
#   'TN',
#   'AR',
#   'MO',
#   'TN',
#   'KS',
#   'PA',
#   'AL',
#   'FL',
#   'IL',
#   'KS',
#   'VA',
#   'MO',
#   'FL',
#   'SC',
#   'LA',
#   'OK',
#   'KY',
#   'FL',
#   'AL',
#   'KY',
#   'OH',
#   'FL',
#   'OK',
#   'AL',
#   'IA',
#   'TX',
#   'NY',
#   'AL',
#   'MO',
#   'PA',
#   'FL',
#   'GA',
#   'VA',
#   'LA',
#   'FL',
#   'IN',
#   'AL',
#   'FL',
#   'VA',
#   'FL',
#   'PA',
#   'IL',
#   'OH',
#   'AL',
#   'PA',
#   'FL',
#   'SC',
#   'GA',
#   'KY',
#   'AL',
#   'WI',
#   'WV',
#   'NY',
#   'WV',
#   'LA',
#   'KY',
#   'KS',
#   'TX',
#   'AR',
#   'FL',
#   'OH',
#   'AR',
#   'IN',
#   'LA',
#   'AR',
#   'FL',
#   'KS',
#   'TX',
#   'IN',
#   'MS',
#   'NE',
#   'FL',
#   'NY',
#   'GA',
#   'FL',
#   'GA',
#   'AL',
#   'SC',
#   'TX',
#   'GA',
#   'FL',
#   'NM',
#   'KS',
#   'AL',
#   'OH',
#   'FL',
#   'TN',
#   'OH',
#   'MO',
#   'FL',
#   'TN',
#   'AR',
#   'VA',
#   'OH',
#   'MO',
#   'TX',
#   'KS',
#   'IN',
#   'WV',
#   'FL',
#   'FL',
#   'TX',
#   'TN',
#   'TX',
#   'KS',
#   'AR',
#   'FL',
#   'OH',
#   'IN',
#   'PA',
#   'IN',
#   'NC',
#   'AL',
#   'TX',
#   'IN',
#   'FL',
#   'OH',
#   'SC',
#   'AL',
#   'PA',
#   'LA',
#   'TN',
#   'GA',
#   'FL',
#   'FL',
#   'IL',
#   'MT',
#   'IA',
#   'FL',
#   'WI',
#   'FL',
#   'WI',
#   'AL',
#   'MD',
#   'VA',
#   'WV',
#   'TN',
#   'TX',
#   'IL',
#   'TN',
#   'WI',
#   'MS',
#   'OH',
#   'TX',
#   'IA',
#   'NY',
#   'TX',
#   'IL',
#   'IA',
#   'FL',
#   'GA',
#   'TX',
#   'TX',
#   'NC',
#   'WI',
#   'SC',
#   'TN',
#   'MS',
#   'PA',
#   'NY',
#   'AL',
#   'FL',
#   'LA',
#   'MO',
#   'NC',
#   'AL',
#   'LA',
#   'WI',
#   'OK',
#   'OH',
#   'MO',
#   'MO',
#   'PA',
#   'AR',
#   'TN',
#   'AR',
#   'SC',
#   'MD',
#   'MI',
#   'FL',
#   'FL',
#   'FL',
#   'FL',
#   'OH',
#   'FL',
#   'IA',
#   'KY',
#   'NC',
#   'AL',
#   'FL',
#   'IL',
#   'FL',
#   'MO',
#   'FL',
#   'IA',
#   'WI',
#   'FL',
#   'MS',
#   'IL',
#   'KY',
#   'OH',
#   'IA',
#   'LA',
#   'FL',
#   'OH',
#   'FL',
#   'IL',
#   'TX',
#   'FL',
#   'KY',
#   'MO',
#   'PA',
#   'OH',
#   'NC',
#   'FL',
#   'NM',
#   'FL',
#   'FL',
#   'NY',
#   'CO',
#   'WI',
#   'AL',
#   'KY',
#   'MO',
#   'TX',
#   'GA',
#   'IN',
#   'IN',
#   'NM',
#   'IA',
#   'TX',
#   'MO',
#   'TX',
#   'MI',
#   'FL',
#   'WV',
#   'OH',
#   'OH',
#   'PA',
#   'TX',
#   'IL',
#   'TX',
#   'TX',
#   'AR',
#   'PA',
#   'AZ',
#   'TX',
#   'NV',
#   'FL',
#   'FL',
#   'PA',
#   'TX',
#   'GA',
#   'FL',
#   'PA',
#   'TX',
#   'TX',
#   'AL',
#   'MI',
#   'TN',
#   'NC',
#   'FL',
#   'TX',
#   'FL',
#   'FL',
#   'MO',
#   'MO',
#   'TX',
#   'TN',
#   'VA',
#   'GA',
#   'MS',
#   'TX',
#   'MO',
#   'ND',
#   'IL',
#   'OH',
#   'MS',
#   'NM',
#   'IL',
#   'TN',
#   'OH',
#   'NC',
#   'IN',
#   'AZ',
#   'OH',
#   'AZ',
#   'PA',
#   'AR',
#   'PA',
#   'MO',
#   'TN',
#   'AZ',
#   'GA',
#   'IN',
#   'IN',
#   'MS',
#   'LA',
#   'NE',
#   'KS',
#   'ND',
#   'NH',
#   'MS',
#   'AZ',
#   'OR',
#   'TN',
#   'MS',
#   'IL',
#   'MD',
#   'IN',
#   'NJ',
#   'IN',
#   'GA',
#   'AL',
#   'VA',
#   'KY',
#   'ID',
#   'FL',
#   'CO',
#   'TX',
#   'WI',
#   'TX',
#   'FL',
#   'OH',
#   'WI',
#   'MO',
#   'VA',
#   'MT',
#   'TX',
#   'IN',
#   'OR',
#   'AR',
#   'TX',
#   'GA',
#   'FL',
#   'FL',
#   'TN',
#   'AR',
#   'TX',
#   'LA',
#   'GA',
#   'IL',
#   'NC',
#   'NJ',
#   'NJ',
#   'TX',
#   'TN',
#   'MI',
#   'NJ',
#   'AL',
#   'MO',
#   'OH',
#   'FL',
#   'TN',
#   'IA',
#   'FL',
#   'AR',
#   'MO',
#   'IN',
#   'MN',
#   'GA',
#   'PA',
#   'TX',
#   'PA',
#   'TX',
#   'OH',
#   'VA',
#   'TX',
#   'NM',
#   'LA',
#   'OR',
#   'MI',
#   'PA',
#   'IN',
#   'VA',
#   'NH',
#   'CO',
#   'NY',
#   'IN',
#   'ID',
#   'MS',
#   'KS',
#   'OH',
#   'VA',
#   'FL',
#   'AZ',
#   'MI',
#   'GA',
#   'IA',
#   'FL',
#   'MI',
#   'OK',
#   'NV',
#   'UT',
#   'MS',
#   'IL',
#   'MS',
#   'IL',
#   'TX',
#   'NJ',
#   'NJ',
#   'TN',
#   'TX',
#   'MI',
#   'WI',
#   'ID',
#   'MI',
#   'IN',
#   'PA',
#   'MT',
#   'FL',
#   'OK',
#   'ID',
#   'WI',
#   'KS',
#   'TN',
#   'ND',
#   'IN',
#   'TX',
#   'NJ',
#   'TN',
#   'ND',
#   'OH',
#   'PA',
#   'LA',
#   'ME',
#   'SD',
#   'MI',
#   'GA',
#   'IN',
#   'NC',
#   'IA',
#   'SC',
#   'VA',
#   'TN',
#   'MS',
#   'TX',
#   'IN',
#   'ID',
#   'IA',
#   'LA',
#   'LA',
#   'MN',
#   'FL',
#   'TX',
#   'PA',
#   'GA',
#   'CA',
#   'IL',
#   'FL',
#   'NC',
#   'OH',
#   'UT',
#   'MO',
#   'NE',
#   'IL',
#   'SC',
#   'KY',
#   'TX',
#   'NC',
#   'TX',
#   'MI',
#   'MI',
#   'NJ',
#   'MN',
#   'WV',
#   'GA',
#   'TX',
#   'OH',
#   'TX',
#   'IL',
#   'VA',
#   'FL',
#   'NY',
#   'OH',
#   'AR',
#   'OR',
#   'MD',
#   'NJ',
#   'TN',
#   'OH',
#   'MI',
#   'OH',
#   'MO',
#   'VA',
#   'WA',
#   'CA',
#   'FL',
#   'TX',
#   'SC',
#   'MO',
#   'CA',
#   'NJ',
#   'AZ',
#   'WA',
#   'CA',
#   'GA',
#   'IN',
#   'CO',
#   'CA',
#   'IN',
#   'FL',
#   'LA',
#   'TX',
#   'AR',
#   'VA',
#   'NH',
#   'NE',
#   'IL',
#   'NC',
#   'TX',
#   'VA',
#   'NC',
#   'GA',
#   'SD',
#   'NC',
#   'IL',
#   'UT',
#   'WA',
#   'VA',
#   'NY',
#   'WV',
#   'WA',
#   'WI',
#   'IN',
#   'VA',
#   'MA',
#   'VA',
#   'TX',
#   'IL',
#   'KS',
#   'AZ',
#   'MS',
#   'GA',
#   'MI',
#   'IL',
#   'AZ',
#   'TX',
#   'LA',
#   'MI',
#   'TX',
#   'NJ',
#   'IA',
#   'ND',
#   'NH',
#   'FL',
#   'MT',
#   'SC',
#   'CO',
#   'WI',
#   'NV',
#   'IL',
#   'NY',
#   'KS',
#   'IL',
#   'TN',
#   'AL',
#   'IL',
#   'WI',
#   'IN',
#   'MI',
#   'IL',
#   'DE',
#   'NY',
#   'IN',
#   'CT',
#   'NM',
#   'MN',
#   'IL',
#   'OH',
#   'MI',
#   'IL',
#   'IL',
#   'OR',
#   'SD',
#   'WI',
#   'MO',
#   'CA',
#   'NE',
#   'WI',
#   'SC',
#   'ND',
#   'CA',
#   'TN',
#   'FL',
#   'OH',
#   'IL',
#   'MI',
#   'MD',
#   'PA',
#   'KY',
#   'IL',
#   'FL',
#   'NH',
#   'OH',
#   'VA',
#   'OR',
#   'FL',
#   'IL',
#   'CA',
#   'OK',
#   'NC',
#   'TX',
#   'TN',
#   'LA',
#   'KY',
#   'MN',
#   'CA',
#   'OH',
#   'KY',
#   'NM',
#   'AZ',
#   'WA',
#   'KY',
#   'IL',
#   'NV',
#   'MI',
#   'IN',
#   'SC',
#   'GA',
#   'SC',
#   'IL',
#   'OH',
#   'PA',
#   'NJ',
#   'NC',
#   'TX',
#   'PA',
#   'MA',
#   'PA',
#   'FL',
#   'FL',
#   'IL',
#   'VA',
#   'VA',
#   'OH',
#   'NY',
#   'OH',
#   'TX',
#   'PA',
#   'NV',
#   'MA',
#   'PA',
#   'OH',
#   'AZ',
#   'LA',
#   'TX',
#   'NJ',
#   'TX',
#   'NY',
#   'NC',
#   'NY',
#   'MO',
#   'TX',
#   'WA',
#   'AZ',
#   'PA',
#   'CO',
#   'GA',
#   'SC',
#   'IL',
#   'MA',
#   'TN',
#   'NJ',
#   'CA',
#   'TX',
#   'CA',
#   'OH',
#   'TX',
#   'VA',
#   'WA',
#   'AZ',
#   'IN',
#   'NC',
#   'GA',
#   'NV',
#   'CA',
#   'WI',
#   'MI',
#   'IN',
#   'CT',
#   'WI',
#   'VA',
#   'LA',
#   'NV',
#   'MI',
#   'FL',
#   'MA',
#   'FL',
#   'WA',
#   'LA',
#   'MA',
#   'NH',
#   'OR',
#   'NC',
#   'TX',
#   'AZ',
#   'CA',
#   'LA',
#   'NC',
#   'FL',
#   'FL',
#   'NJ',
#   'MT',
#   'AZ',
#   'IN',
#   'MO',
#   'TX',
#   'PA',
#   'TX',
#   'CA',
#   'NY',
#   'NJ',
#   'AZ',
#   'NE',
#   'MI',
#   'GA',
#   'UT',
#   'RI',
#   'NY',
#   'TX',
#   'CA',
#   'PA',
#   'MI',
#   'WA',
#   'WI',
#   'CA',
#   'OR',
#   'CA',
#   'OK',
#   'IL',
#   'CA',
#   'MN',
#   'DE',
#   'NE',
#   'ME',
#   'MI',
#   'UT',
#   'PA',
#   'CA',
#   'IN',
#   'FL',
#   'IN',
#   'NY',
#   'MI',
#   'CT',
#   'NY',
#   'MN',
#   'TX',
#   'WA',
#   'NY',
#   'OR',
#   'MI',
#   'MA',
#   'KS',
#   'MI',
#   'CA',
#   'FL',
#   'ME',
#   'NJ',
#   'CT',
#   'KS',
#   'FL',
#   'WI',
#   'OH',
#   'TX',
#   'SC',
#   'MA',
#   'KY',
#   'OH',
#   'MI',
#   'MD',
#   'NC',
#   'IN',
#   'TX',
#   'NJ',
#   'MA',
#   'IL',
#   'NY',
#   'NV',
#   'CA',
#   'CA',
#   'MI',
#   'RI',
#   'PA',
#   'TX',
#   'CA',
#   'TX',
#   'NY',
#   'KS',
#   'MA',
#   'DE',
#   'WA',
#   'KY',
#   'PA',
#   'TX',
#   'CA',
#   'MA',
#   'MO',
#   'MN',
#   'GA',
#   'CA',
#   'OR',
#   'IL',
#   'MI',
#   'NY',
#   'CA',
#   'AZ',
#   'NY',
#   'FL',
#   'CA',
#   'NE',
#   'MI',
#   'UT',
#   'NY',
#   'CO',
#   'CO',
#   'MI',
#   'WA',
#   'NJ',
#   'IL',
#   'MN',
#   'MI',
#   'CT',
#   'MD',
#   'TX',
#   'LA',
#   'WA',
#   'NJ',
#   'OK',
#   'WI',
#   'MI',
#   'AZ',
#   'TX',
#   'NV',
#   'VA',
#   'MA',
#   'CA',
#   'CA',
#   'WA',
#   'PA',
#   'KY',
#   'AZ',
#   'AZ',
#   'IL',
#   'OH',
#   'NV',
#   'CA',
#   'CT',
#   'NJ',
#   'OK',
#   'PA',
#   'VA',
#   'TX',
#   'MN',
#   'FL',
#   'CA',
#   'CA',
#   'WA',
#   'SD',
#   'NJ',
#   'NJ',
#   'IL',
#   'CA',
#   'CA',
#   'NJ',
#   'CT',
#   'MO',
#   'MI',
#   'OK',
#   'CT',
#   'ID',
#   'NY',
#   'MI',
#   'MA',
#   'TX',
#   'NY',
#   'IL',
#   'NC',
#   'MA',
#   'PA',
#   'MA',
#   'NJ',
#   'WY',
#   'CA',
#   'NJ',
#   'CA',
#   'OH',
#   'CA',
#   'CT',
#   'TX',
#   'AL',
#   'MN',
#   'MN',
#   'NY',
#   'NV',
#   'TX',
#   'PA',
#   'OH',
#   'SC',
#   'CT',
#   'WI',
#   'CA',
#   'FL',
#   'WA',
#   'NJ',
#   'MD',
#   'MA',
#   'LA',
#   'CA',
#   'SC',
#   'MD',
#   'NY',
#   'SC',
#   'IL',
#   'PA',
#   'OH',
#   'NC',
#   'CA',
#   'FL',
#   'TN',
#   'GA',
#   'NJ',
#   'WI',
#   'CA',
#   'WA',
#   'MD',
#   'CA',
#   'OH',
#   'CA',
#   'CO',
#   'WA',
#   'NH',
#   'AK',
#   'TX',
#   'NY',
#   'CT',
#   'DC',
#   'OR',
#   'MO',
#   'MA',
#   'MI',
#   'MN',
#   'CA',
#   ...],
#  '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC': ['AZ',
#   'MA',
#   'TX',
#   'MS',
#   'MI',
#   'PA',
#   'NY',
#   'WI',
#   'IL',
#   'MA',
#   'MD',
#   'IL',
#   'LA',
#   'DC',
#   'VA',
#   'MD',
#   'NY',
#   'CA',
#   'CA',
#   'MD',
#   'HI',
#   'AZ',
#   'NY',
#   'CA',
#   'NY',
#   'NY',
#   'MD',
#   'MA',
#   'NY',
#   'CA',
#   'CA',
#   'NY',
#   'CA',
#   'NY',
#   'MD',
#   'CA',
#   'CA',
#   'WA',
#   'MD',
#   'NY',
#   'MN',
#   'NY',
#   'CA',
#   'MD',
#   'IL',
#   'IL',
#   'AL',
#   'AL',
#   'MO',
#   'IN',
#   'WV',
#   'TN',
#   'PA',
#   'PA',
#   'TN',
#   'TN',
#   'TN',
#   'AR',
#   'MO',
#   'TN',
#   'KS',
#   'PA',
#   'AL',
#   'FL',
#   'IL',
#   'KS',
#   'VA',
#   'MO',
#   'FL',
#   'SC',
#   'LA',
#   'OK',
#   'KY',
#   'FL',
#   'AL',
#   'KY',
#   'OH',
#   'FL',
#   'OK',
#   'AL',
#   'IA',
#   'TX',
#   'NY',
#   'AL',
#   'MO',
#   'PA',
#   'FL',
#   'GA',
#   'VA',
#   'LA',
#   'FL',
#   'IN',
#   'AL',
#   'FL',
#   'VA',
#   'FL',
#   'PA',
#   'IL',
#   'OH',
#   'AL',
#   'PA',
#   'FL',
#   'SC',
#   'GA',
#   'KY',
#   'AL',
#   'WI',
#   'WV',
#   'NY',
#   'WV',
#   'LA',
#   'KY',
#   'KS',
#   'TX',
#   'AR',
#   'FL',
#   'OH',
#   'AR',
#   'IN',
#   'LA',
#   'AR',
#   'FL',
#   'KS',
#   'TX',
#   'IN',
#   'MS',
#   'NE',
#   'FL',
#   'NY',
#   'GA',
#   'FL',
#   'GA',
#   'AL',
#   'SC',
#   'TX',
#   'GA',
#   'FL',
#   'NM',
#   'KS',
#   'AL',
#   'OH',
#   'FL',
#   'TN',
#   'OH',
#   'MO',
#   'FL',
#   'TN',
#   'AR',
#   'VA',
#   'OH',
#   'MO',
#   'TX',
#   'KS',
#   'IN',
#   'WV',
#   'FL',
#   'FL',
#   'TX',
#   'TN',
#   'TX',
#   'KS',
#   'AR',
#   'FL',
#   'OH',
#   'IN',
#   'PA',
#   'IN',
#   'NC',
#   'AL',
#   'TX',
#   'IN',
#   'FL',
#   'OH',
#   'SC',
#   'AL',
#   'PA',
#   'LA',
#   'TN',
#   'GA',
#   'FL',
#   'FL',
#   'IL',
#   'MT',
#   'IA',
#   'FL',
#   'WI',
#   'FL',
#   'WI',
#   'AL',
#   'MD',
#   'VA',
#   'WV',
#   'TN',
#   'TX',
#   'IL',
#   'TN',
#   'WI',
#   'MS',
#   'OH',
#   'TX',
#   'IA',
#   'NY',
#   'TX',
#   'IL',
#   'IA',
#   'FL',
#   'GA',
#   'TX',
#   'TX',
#   'NC',
#   'WI',
#   'SC',
#   'TN',
#   'MS',
#   'PA',
#   'NY',
#   'AL',
#   'FL',
#   'LA',
#   'MO',
#   'NC',
#   'AL',
#   'LA',
#   'WI',
#   'OK',
#   'OH',
#   'MO',
#   'MO',
#   'PA',
#   'AR',
#   'TN',
#   'AR',
#   'SC',
#   'MD',
#   'MI',
#   'FL',
#   'FL',
#   'FL',
#   'FL',
#   'OH',
#   'FL',
#   'IA',
#   'KY',
#   'NC',
#   'AL',
#   'FL',
#   'IL',
#   'FL',
#   'MO',
#   'FL',
#   'IA',
#   'WI',
#   'FL',
#   'MS',
#   'IL',
#   'KY',
#   'OH',
#   'IA',
#   'LA',
#   'FL',
#   'OH',
#   'FL',
#   'IL',
#   'TX',
#   'FL',
#   'KY',
#   'MO',
#   'PA',
#   'OH',
#   'NC',
#   'FL',
#   'NM',
#   'FL',
#   'FL',
#   'NY',
#   'CO',
#   'WI',
#   'AL',
#   'KY',
#   'MO',
#   'TX',
#   'GA',
#   'IN',
#   'IN',
#   'NM',
#   'IA',
#   'TX',
#   'MO',
#   'TX',
#   'MI',
#   'FL',
#   'WV',
#   'OH',
#   'OH',
#   'PA',
#   'TX',
#   'IL',
#   'TX',
#   'TX',
#   'AR',
#   'PA',
#   'AZ',
#   'TX',
#   'NV',
#   'FL',
#   'FL',
#   'PA',
#   'TX',
#   'GA',
#   'FL',
#   'PA',
#   'TX',
#   'TX',
#   'AL',
#   'MI',
#   'TN',
#   'NC',
#   'FL',
#   'TX',
#   'FL',
#   'FL',
#   'MO',
#   'MO',
#   'TX',
#   'TN',
#   'VA',
#   'GA',
#   'MS',
#   'TX',
#   'MO',
#   'ND',
#   'IL',
#   'OH',
#   'MS',
#   'NM',
#   'IL',
#   'TN',
#   'OH',
#   'NC',
#   'IN',
#   'AZ',
#   'OH',
#   'AZ',
#   'PA',
#   'AR',
#   'PA',
#   'MO',
#   'TN',
#   'AZ',
#   'GA',
#   'IN',
#   'IN',
#   'MS',
#   'LA',
#   'NE',
#   'KS',
#   'ND',
#   'NH',
#   'MS',
#   'AZ',
#   'OR',
#   'TN',
#   'MS',
#   'IL',
#   'MD',
#   'IN',
#   'NJ',
#   'IN',
#   'GA',
#   'AL',
#   'VA',
#   'KY',
#   'ID',
#   'FL',
#   'CO',
#   'TX',
#   'WI',
#   'TX',
#   'FL',
#   'OH',
#   'WI',
#   'MO',
#   'VA',
#   'MT',
#   'TX',
#   'IN',
#   'OR',
#   'AR',
#   'TX',
#   'GA',
#   'FL',
#   'FL',
#   'TN',
#   'AR',
#   'TX',
#   'LA',
#   'GA',
#   'IL',
#   'NC',
#   'NJ',
#   'NJ',
#   'TX',
#   'TN',
#   'MI',
#   'NJ',
#   'AL',
#   'MO',
#   'OH',
#   'FL',
#   'TN',
#   'IA',
#   'FL',
#   'AR',
#   'MO',
#   'IN',
#   'MN',
#   'GA',
#   'PA',
#   'TX',
#   'PA',
#   'TX',
#   'OH',
#   'VA',
#   'TX',
#   'NM',
#   'LA',
#   'OR',
#   'MI',
#   'PA',
#   'IN',
#   'VA',
#   'NH',
#   'CO',
#   'NY',
#   'IN',
#   'ID',
#   'MS',
#   'KS',
#   'OH',
#   'VA',
#   'FL',
#   'AZ',
#   'MI',
#   'GA',
#   'IA',
#   'FL',
#   'MI',
#   'OK',
#   'NV',
#   'UT',
#   'MS',
#   'IL',
#   'MS',
#   'IL',
#   'TX',
#   'NJ',
#   'NJ',
#   'TN',
#   'TX',
#   'MI',
#   'WI',
#   'ID',
#   'MI',
#   'IN',
#   'PA',
#   'MT',
#   'FL',
#   'OK',
#   'ID',
#   'WI',
#   'KS',
#   'TN',
#   'ND',
#   'IN',
#   'TX',
#   'NJ',
#   'TN',
#   'ND',
#   'OH',
#   'PA',
#   'LA',
#   'ME',
#   'SD',
#   'MI',
#   'GA',
#   'IN',
#   'NC',
#   'IA',
#   'SC',
#   'VA',
#   'TN',
#   'MS',
#   'TX',
#   'IN',
#   'ID',
#   'IA',
#   'LA',
#   'LA',
#   'MN',
#   'FL',
#   'TX',
#   'PA',
#   'GA',
#   'CA',
#   'IL',
#   'FL',
#   'NC',
#   'OH',
#   'UT',
#   'MO',
#   'NE',
#   'IL',
#   'SC',
#   'KY',
#   'TX',
#   'NC',
#   'TX',
#   'MI',
#   'MI',
#   'NJ',
#   'MN',
#   'WV',
#   'GA',
#   'TX',
#   'OH',
#   'TX',
#   'IL',
#   'VA',
#   'FL',
#   'NY',
#   'OH',
#   'AR',
#   'OR',
#   'MD',
#   'NJ',
#   'TN',
#   'OH',
#   'MI',
#   'OH',
#   'MO',
#   'VA',
#   'WA',
#   'CA',
#   'FL',
#   'TX',
#   'SC',
#   'MO',
#   'CA',
#   'NJ',
#   'AZ',
#   'WA',
#   'CA',
#   'GA',
#   'IN',
#   'CO',
#   'CA',
#   'IN',
#   'FL',
#   'LA',
#   'TX',
#   'AR',
#   'VA',
#   'NH',
#   'NE',
#   'IL',
#   'NC',
#   'TX',
#   'VA',
#   'NC',
#   'GA',
#   'SD',
#   'NC',
#   'IL',
#   'UT',
#   'WA',
#   'VA',
#   'NY',
#   'WV',
#   'WA',
#   'WI',
#   'IN',
#   'VA',
#   'MA',
#   'VA',
#   'TX',
#   'IL',
#   'KS',
#   'AZ',
#   'MS',
#   'GA',
#   'MI',
#   'IL',
#   'AZ',
#   'TX',
#   'LA',
#   'MI',
#   'TX',
#   'NJ',
#   'IA',
#   'ND',
#   'NH',
#   'FL',
#   'MT',
#   'SC',
#   'CO',
#   'WI',
#   'NV',
#   'IL',
#   'NY',
#   'KS',
#   'IL',
#   'TN',
#   'AL',
#   'IL',
#   'WI',
#   'IN',
#   'MI',
#   'IL',
#   'DE',
#   'NY',
#   'IN',
#   'CT',
#   'NM',
#   'MN',
#   'IL',
#   'OH',
#   'MI',
#   'IL',
#   'IL',
#   'OR',
#   'SD',
#   'WI',
#   'MO',
#   'CA',
#   'NE',
#   'WI',
#   'SC',
#   'ND',
#   'CA',
#   'TN',
#   'FL',
#   'OH',
#   'IL',
#   'MI',
#   'MD',
#   'PA',
#   'KY',
#   'IL',
#   'FL',
#   'NH',
#   'OH',
#   'VA',
#   'OR',
#   'FL',
#   'IL',
#   'CA',
#   'OK',
#   'NC',
#   'TX',
#   'TN',
#   'LA',
#   'KY',
#   'MN',
#   'CA',
#   'OH',
#   'KY',
#   'NM',
#   'AZ',
#   'WA',
#   'KY',
#   'IL',
#   'NV',
#   'MI',
#   'IN',
#   'SC',
#   'GA',
#   'SC',
#   'IL',
#   'OH',
#   'PA',
#   'NJ',
#   'NC',
#   'TX',
#   'PA',
#   'MA',
#   'PA',
#   'FL',
#   'FL',
#   'IL',
#   'VA',
#   'VA',
#   'OH',
#   'NY',
#   'OH',
#   'TX',
#   'PA',
#   'NV',
#   'MA',
#   'PA',
#   'OH',
#   'AZ',
#   'LA',
#   'TX',
#   'NJ',
#   'TX',
#   'NY',
#   'NC',
#   'NY',
#   'MO',
#   'TX',
#   'WA',
#   'AZ',
#   'PA',
#   'CO',
#   'GA',
#   'SC',
#   'IL',
#   'MA',
#   'TN',
#   'NJ',
#   'CA',
#   'TX',
#   'CA',
#   'OH',
#   'TX',
#   'VA',
#   'WA',
#   'AZ',
#   'IN',
#   'NC',
#   'GA',
#   'NV',
#   'CA',
#   'WI',
#   'MI',
#   'IN',
#   'CT',
#   'WI',
#   'VA',
#   'LA',
#   'NV',
#   'MI',
#   'FL',
#   'MA',
#   'FL',
#   'WA',
#   'LA',
#   'MA',
#   'NH',
#   'OR',
#   'NC',
#   'TX',
#   'AZ',
#   'CA',
#   'LA',
#   'NC',
#   'FL',
#   'FL',
#   'NJ',
#   'MT',
#   'AZ',
#   'IN',
#   'MO',
#   'TX',
#   'PA',
#   'TX',
#   'CA',
#   'NY',
#   'NJ',
#   'AZ',
#   'NE',
#   'MI',
#   'GA',
#   'UT',
#   'RI',
#   'NY',
#   'TX',
#   'CA',
#   'PA',
#   'MI',
#   'WA',
#   'WI',
#   'CA',
#   'OR',
#   'CA',
#   'OK',
#   'IL',
#   'CA',
#   'MN',
#   'DE',
#   'NE',
#   'ME',
#   'MI',
#   'UT',
#   'PA',
#   'CA',
#   'IN',
#   'FL',
#   'IN',
#   'NY',
#   'MI',
#   'CT',
#   'NY',
#   'MN',
#   'TX',
#   'WA',
#   'NY',
#   'OR',
#   'MI',
#   'MA',
#   'KS',
#   'MI',
#   'CA',
#   'FL',
#   'ME',
#   'NJ',
#   'CT',
#   'KS',
#   'FL',
#   'WI',
#   'OH',
#   'TX',
#   'SC',
#   'MA',
#   'KY',
#   'OH',
#   'MI',
#   'MD',
#   'NC',
#   'IN',
#   'TX',
#   'NJ',
#   'MA',
#   'IL',
#   'NY',
#   'NV',
#   'CA',
#   'CA',
#   'MI',
#   'RI',
#   'PA',
#   'TX',
#   'CA',
#   'TX',
#   'NY',
#   'KS',
#   'MA',
#   'DE',
#   'WA',
#   'KY',
#   'PA',
#   'TX',
#   'CA',
#   'MA',
#   'MO',
#   'MN',
#   'GA',
#   'CA',
#   'OR',
#   'IL',
#   'MI',
#   'NY',
#   'CA',
#   'AZ',
#   'NY',
#   'FL',
#   'CA',
#   'NE',
#   'MI',
#   'UT',
#   'NY',
#   'CO',
#   'CO',
#   'MI',
#   'WA',
#   'NJ',
#   'IL',
#   'MN',
#   'MI',
#   'CT',
#   'MD',
#   'TX',
#   'LA',
#   'WA',
#   'NJ',
#   'OK',
#   'WI',
#   'MI',
#   'AZ',
#   'TX',
#   'NV',
#   'VA',
#   'MA',
#   'CA',
#   'CA',
#   'WA',
#   'PA',
#   'KY',
#   'AZ',
#   'AZ',
#   'IL',
#   'OH',
#   'NV',
#   'CA',
#   'CT',
#   'NJ',
#   'OK',
#   'PA',
#   'VA',
#   'TX',
#   'MN',
#   'FL',
#   'CA',
#   'CA',
#   'WA',
#   'SD',
#   'NJ',
#   'NJ',
#   'IL',
#   'CA',
#   'CA',
#   'NJ',
#   'CT',
#   'MO',
#   'MI',
#   'OK',
#   'CT',
#   'ID',
#   'NY',
#   'MI',
#   'MA',
#   'TX',
#   'NY',
#   'IL',
#   'NC',
#   'MA',
#   'PA',
#   'MA',
#   'NJ',
#   'WY',
#   'CA',
#   'NJ',
#   'CA',
#   'OH',
#   'CA',
#   'CT',
#   'TX',
#   'AL',
#   'MN',
#   'MN',
#   'NY',
#   'NV',
#   'TX',
#   'PA',
#   'OH',
#   'SC',
#   'CT',
#   'WI',
#   'CA',
#   'FL',
#   'WA',
#   'NJ',
#   'MD',
#   'MA',
#   'LA',
#   'CA',
#   'SC',
#   'MD',
#   'NY',
#   'SC',
#   'IL',
#   'PA',
#   'OH',
#   'NC',
#   'CA',
#   'FL',
#   'TN',
#   'GA',
#   'NJ',
#   'WI',
#   'CA',
#   'WA',
#   'MD',
#   'CA',
#   'OH',
#   'CA',
#   'CO',
#   'WA',
#   'NH',
#   'AK',
#   'TX',
#   'NY',
#   'CT',
#   'DC',
#   'OR',
#   'MO',
#   'MA',
#   'MI',
#   'MN',
#   'CA',
#   ...],
#  '069 - TRANSIENT ISCHEMIA': ['AZ',
#   'MA',
#   'TX',
#   'MS',
#   'MI',
#   'PA',
#   'NY',
#   'WI',
#   'IL',
#   'MA',
#   'MD',
#   'IL',
#   'LA',
#   'DC',
#   'VA',
#   'MD',
#   'NY',
#   'CA',
#   'CA',
#   'MD',
#   'HI',
#   'AZ',
#   'NY',
#   'CA',
#   'NY',
#   'NY',
#   'MD',
#   'MA',
#   'NY',
#   'CA',
#   'CA',
#   'NY',
#   'CA',
#   'NY',
#   'MD',
#   'CA',
#   'CA',
#   'WA',
#   'MD',
#   'NY',
#   'MN',
#   'NY',
#   'CA',
#   'MD',
#   'IL',
#   'IL',
#   'AL',
#   'AL',
#   'MO',
#   'IN',
#   'WV',
#   'TN',
#   'PA',
#   'PA',
#   'TN',
#   'TN',
#   'TN',
#   'AR',
#   'MO',
#   'TN',
#   'KS',
#   'PA',
#   'AL',
#   'FL',
#   'IL',
#   'KS',
#   'VA',
#   'MO',
#   'FL',
#   'SC',
#   'LA',
#   'OK',
#   'KY',
#   'FL',
#   'AL',
#   'KY',
#   'OH',
#   'FL',
#   'OK',
#   'AL',
#   'IA',
#   'TX',
#   'NY',
#   'AL',
#   'MO',
#   'PA',
#   'FL',
#   'GA',
#   'VA',
#   'LA',
#   'FL',
#   'IN',
#   'AL',
#   'FL',
#   'VA',
#   'FL',
#   'PA',
#   'IL',
#   'OH',
#   'AL',
#   'PA',
#   'FL',
#   'SC',
#   'GA',
#   'KY',
#   'AL',
#   'WI',
#   'WV',
#   'NY',
#   'WV',
#   'LA',
#   'KY',
#   'KS',
#   'TX',
#   'AR',
#   'FL',
#   'OH',
#   'AR',
#   'IN',
#   'LA',
#   'AR',
#   'FL',
#   'KS',
#   'TX',
#   'IN',
#   'MS',
#   'NE',
#   'FL',
#   'NY',
#   'GA',
#   'FL',
#   'GA',
#   'AL',
#   'SC',
#   'TX',
#   'GA',
#   'FL',
#   'NM',
#   'KS',
#   'AL',
#   'OH',
#   'FL',
#   'TN',
#   'OH',
#   'MO',
#   'FL',
#   'TN',
#   'AR',
#   'VA',
#   'OH',
#   'MO',
#   'TX',
#   'KS',
#   'IN',
#   'WV',
#   'FL',
#   'FL',
#   'TX',
#   'TN',
#   'TX',
#   'KS',
#   'AR',
#   'FL',
#   'OH',
#   'IN',
#   'PA',
#   'IN',
#   'NC',
#   'AL',
#   'TX',
#   'IN',
#   'FL',
#   'OH',
#   'SC',
#   'AL',
#   'PA',
#   'LA',
#   'TN',
#   'GA',
#   'FL',
#   'FL',
#   'IL',
#   'MT',
#   'IA',
#   'FL',
#   'WI',
#   'FL',
#   'WI',
#   'AL',
#   'MD',
#   'VA',
#   'WV',
#   'TN',
#   'TX',
#   'IL',
#   'TN',
#   'WI',
#   'MS',
#   'OH',
#   'TX',
#   'IA',
#   'NY',
#   'TX',
#   'IL',
#   'IA',
#   'FL',
#   'GA',
#   'TX',
#   'TX',
#   'NC',
#   'WI',
#   'SC',
#   'TN',
#   'MS',
#   'PA',
#   'NY',
#   'AL',
#   'FL',
#   'LA',
#   'MO',
#   'NC',
#   'AL',
#   'LA',
#   'WI',
#   'OK',
#   'OH',
#   'MO',
#   'MO',
#   'PA',
#   'AR',
#   'TN',
#   'AR',
#   'SC',
#   'MD',
#   'MI',
#   'FL',
#   'FL',
#   'FL',
#   'FL',
#   'OH',
#   'FL',
#   'IA',
#   'KY',
#   'NC',
#   'AL',
#   'FL',
#   'IL',
#   'FL',
#   'MO',
#   'FL',
#   'IA',
#   'WI',
#   'FL',
#   'MS',
#   'IL',
#   'KY',
#   'OH',
#   'IA',
#   'LA',
#   'FL',
#   'OH',
#   'FL',
#   'IL',
#   'TX',
#   'FL',
#   'KY',
#   'MO',
#   'PA',
#   'OH',
#   'NC',
#   'FL',
#   'NM',
#   'FL',
#   'FL',
#   'NY',
#   'CO',
#   'WI',
#   'AL',
#   'KY',
#   'MO',
#   'TX',
#   'GA',
#   'IN',
#   'IN',
#   'NM',
#   'IA',
#   'TX',
#   'MO',
#   'TX',
#   'MI',
#   'FL',
#   'WV',
#   'OH',
#   'OH',
#   'PA',
#   'TX',
#   'IL',
#   'TX',
#   'TX',
#   'AR',
#   'PA',
#   'AZ',
#   'TX',
#   'NV',
#   'FL',
#   'FL',
#   'PA',
#   'TX',
#   'GA',
#   'FL',
#   'PA',
#   'TX',
#   'TX',
#   'AL',
#   'MI',
#   'TN',
#   'NC',
#   'FL',
#   'TX',
#   'FL',
#   'FL',
#   'MO',
#   'MO',
#   'TX',
#   'TN',
#   'VA',
#   'GA',
#   'MS',
#   'TX',
#   'MO',
#   'ND',
#   'IL',
#   'OH',
#   'MS',
#   'NM',
#   'IL',
#   'TN',
#   'OH',
#   'NC',
#   'IN',
#   'AZ',
#   'OH',
#   'AZ',
#   'PA',
#   'AR',
#   'PA',
#   'MO',
#   'TN',
#   'AZ',
#   'GA',
#   'IN',
#   'IN',
#   'MS',
#   'LA',
#   'NE',
#   'KS',
#   'ND',
#   'NH',
#   'MS',
#   'AZ',
#   'OR',
#   'TN',
#   'MS',
#   'IL',
#   'MD',
#   'IN',
#   'NJ',
#   'IN',
#   'GA',
#   'AL',
#   'VA',
#   'KY',
#   'ID',
#   'FL',
#   'CO',
#   'TX',
#   'WI',
#   'TX',
#   'FL',
#   'OH',
#   'WI',
#   'MO',
#   'VA',
#   'MT',
#   'TX',
#   'IN',
#   'OR',
#   'AR',
#   'TX',
#   'GA',
#   'FL',
#   'FL',
#   'TN',
#   'AR',
#   'TX',
#   'LA',
#   'GA',
#   'IL',
#   'NC',
#   'NJ',
#   'NJ',
#   'TX',
#   'TN',
#   'MI',
#   'NJ',
#   'AL',
#   'MO',
#   'OH',
#   'FL',
#   'TN',
#   'IA',
#   'FL',
#   'AR',
#   'MO',
#   'IN',
#   'MN',
#   'GA',
#   'PA',
#   'TX',
#   'PA',
#   'TX',
#   'OH',
#   'VA',
#   'TX',
#   'NM',
#   'LA',
#   'OR',
#   'MI',
#   'PA',
#   'IN',
#   'VA',
#   'NH',
#   'CO',
#   'NY',
#   'IN',
#   'ID',
#   'MS',
#   'KS',
#   'OH',
#   'VA',
#   'FL',
#   'AZ',
#   'MI',
#   'GA',
#   'IA',
#   'FL',
#   'MI',
#   'OK',
#   'NV',
#   'UT',
#   'MS',
#   'IL',
#   'MS',
#   'IL',
#   'TX',
#   'NJ',
#   'NJ',
#   'TN',
#   'TX',
#   'MI',
#   'WI',
#   'ID',
#   'MI',
#   'IN',
#   'PA',
#   'MT',
#   'FL',
#   'OK',
#   'ID',
#   'WI',
#   'KS',
#   'TN',
#   'ND',
#   'IN',
#   'TX',
#   'NJ',
#   'TN',
#   'ND',
#   'OH',
#   'PA',
#   'LA',
#   'ME',
#   'SD',
#   'MI',
#   'GA',
#   'IN',
#   'NC',
#   'IA',
#   'SC',
#   'VA',
#   'TN',
#   'MS',
#   'TX',
#   'IN',
#   'ID',
#   'IA',
#   'LA',
#   'LA',
#   'MN',
#   'FL',
#   'TX',
#   'PA',
#   'GA',
#   'CA',
#   'IL',
#   'FL',
#   'NC',
#   'OH',
#   'UT',
#   'MO',
#   'NE',
#   'IL',
#   'SC',
#   'KY',
#   'TX',
#   'NC',
#   'TX',
#   'MI',
#   'MI',
#   'NJ',
#   'MN',
#   'WV',
#   'GA',
#   'TX',
#   'OH',
#   'TX',
#   'IL',
#   'VA',
#   'FL',
#   'NY',
#   'OH',
#   'AR',
#   'OR',
#   'MD',
#   'NJ',
#   'TN',
#   'OH',
#   'MI',
#   'OH',
#   'MO',
#   'VA',
#   'WA',
#   'CA',
#   'FL',
#   'TX',
#   'SC',
#   'MO',
#   'CA',
#   'NJ',
#   'AZ',
#   'WA',
#   'CA',
#   'GA',
#   'IN',
#   'CO',
#   'CA',
#   'IN',
#   'FL',
#   'LA',
#   'TX',
#   'AR',
#   'VA',
#   'NH',
#   'NE',
#   'IL',
#   'NC',
#   'TX',
#   'VA',
#   'NC',
#   'GA',
#   'SD',
#   'NC',
#   'IL',
#   'UT',
#   'WA',
#   'VA',
#   'NY',
#   'WV',
#   'WA',
#   'WI',
#   'IN',
#   'VA',
#   'MA',
#   'VA',
#   'TX',
#   'IL',
#   'KS',
#   'AZ',
#   'MS',
#   'GA',
#   'MI',
#   'IL',
#   'AZ',
#   'TX',
#   'LA',
#   'MI',
#   'TX',
#   'NJ',
#   'IA',
#   'ND',
#   'NH',
#   'FL',
#   'MT',
#   'SC',
#   'CO',
#   'WI',
#   'NV',
#   'IL',
#   'NY',
#   'KS',
#   'IL',
#   'TN',
#   'AL',
#   'IL',
#   'WI',
#   'IN',
#   'MI',
#   'IL',
#   'DE',
#   'NY',
#   'IN',
#   'CT',
#   'NM',
#   'MN',
#   'IL',
#   'OH',
#   'MI',
#   'IL',
#   'IL',
#   'OR',
#   'SD',
#   'WI',
#   'MO',
#   'CA',
#   'NE',
#   'WI',
#   'SC',
#   'ND',
#   'CA',
#   'TN',
#   'FL',
#   'OH',
#   'IL',
#   'MI',
#   'MD',
#   'PA',
#   'KY',
#   'IL',
#   'FL',
#   'NH',
#   'OH',
#   'VA',
#   'OR',
#   'FL',
#   'IL',
#   'CA',
#   'OK',
#   'NC',
#   'TX',
#   'TN',
#   'LA',
#   'KY',
#   'MN',
#   'CA',
#   'OH',
#   'KY',
#   'NM',
#   'AZ',
#   'WA',
#   'KY',
#   'IL',
#   'NV',
#   'MI',
#   'IN',
#   'SC',
#   'GA',
#   'SC',
#   'IL',
#   'OH',
#   'PA',
#   'NJ',
#   'NC',
#   'TX',
#   'PA',
#   'MA',
#   'PA',
#   'FL',
#   'FL',
#   'IL',
#   'VA',
#   'VA',
#   'OH',
#   'NY',
#   'OH',
#   'TX',
#   'PA',
#   'NV',
#   'MA',
#   'PA',
#   'OH',
#   'AZ',
#   'LA',
#   'TX',
#   'NJ',
#   'TX',
#   'NY',
#   'NC',
#   'NY',
#   'MO',
#   'TX',
#   'WA',
#   'AZ',
#   'PA',
#   'CO',
#   'GA',
#   'SC',
#   'IL',
#   'MA',
#   'TN',
#   'NJ',
#   'CA',
#   'TX',
#   'CA',
#   'OH',
#   'TX',
#   'VA',
#   'WA',
#   'AZ',
#   'IN',
#   'NC',
#   'GA',
#   'NV',
#   'CA',
#   'WI',
#   'MI',
#   'IN',
#   'CT',
#   'WI',
#   'VA',
#   'LA',
#   'NV',
#   'MI',
#   'FL',
#   'MA',
#   'FL',
#   'WA',
#   'LA',
#   'MA',
#   'NH',
#   'OR',
#   'NC',
#   'TX',
#   'AZ',
#   'CA',
#   'LA',
#   'NC',
#   'FL',
#   'FL',
#   'NJ',
#   'MT',
#   'AZ',
#   'IN',
#   'MO',
#   'TX',
#   'PA',
#   'TX',
#   'CA',
#   'NY',
#   'NJ',
#   'AZ',
#   'NE',
#   'MI',
#   'GA',
#   'UT',
#   'RI',
#   'NY',
#   'TX',
#   'CA',
#   'PA',
#   'MI',
#   'WA',
#   'WI',
#   'CA',
#   'OR',
#   'CA',
#   'OK',
#   'IL',
#   'CA',
#   'MN',
#   'DE',
#   'NE',
#   'ME',
#   'MI',
#   'UT',
#   'PA',
#   'CA',
#   'IN',
#   'FL',
#   'IN',
#   'NY',
#   'MI',
#   'CT',
#   'NY',
#   'MN',
#   'TX',
#   'WA',
#   'NY',
#   'OR',
#   'MI',
#   'MA',
#   'KS',
#   'MI',
#   'CA',
#   'FL',
#   'ME',
#   'NJ',
#   'CT',
#   'KS',
#   'FL',
#   'WI',
#   'OH',
#   'TX',
#   'SC',
#   'MA',
#   'KY',
#   'OH',
#   'MI',
#   'MD',
#   'NC',
#   'IN',
#   'TX',
#   'NJ',
#   'MA',
#   'IL',
#   'NY',
#   'NV',
#   'CA',
#   'CA',
#   'MI',
#   'RI',
#   'PA',
#   'TX',
#   'CA',
#   'TX',
#   'NY',
#   'KS',
#   'MA',
#   'DE',
#   'WA',
#   'KY',
#   'PA',
#   'TX',
#   'CA',
#   'MA',
#   'MO',
#   'MN',
#   'GA',
#   'CA',
#   'OR',
#   'IL',
#   'MI',
#   'NY',
#   'CA',
#   'AZ',
#   'NY',
#   'FL',
#   'CA',
#   'NE',
#   'MI',
#   'UT',
#   'NY',
#   'CO',
#   'CO',
#   'MI',
#   'WA',
#   'NJ',
#   'IL',
#   'MN',
#   'MI',
#   'CT',
#   'MD',
#   'TX',
#   'LA',
#   'WA',
#   'NJ',
#   'OK',
#   'WI',
#   'MI',
#   'AZ',
#   'TX',
#   'NV',
#   'VA',
#   'MA',
#   'CA',
#   'CA',
#   'WA',
#   'PA',
#   'KY',
#   'AZ',
#   'AZ',
#   'IL',
#   'OH',
#   'NV',
#   'CA',
#   'CT',
#   'NJ',
#   'OK',
#   'PA',
#   'VA',
#   'TX',
#   'MN',
#   'FL',
#   'CA',
#   'CA',
#   'WA',
#   'SD',
#   'NJ',
#   'NJ',
#   'IL',
#   'CA',
#   'CA',
#   'NJ',
#   'CT',
#   'MO',
#   'MI',
#   'OK',
#   'CT',
#   'ID',
#   'NY',
#   'MI',
#   'MA',
#   'TX',
#   'NY',
#   'IL',
#   'NC',
#   'MA',
#   'PA',
#   'MA',
#   'NJ',
#   'WY',
#   'CA',
#   'NJ',
#   'CA',
#   'OH',
#   'CA',
#   'CT',
#   'TX',
#   'AL',
#   'MN',
#   'MN',
#   'NY',
#   'NV',
#   'TX',
#   'PA',
#   'OH',
#   'SC',
#   'CT',
#   'WI',
#   'CA',
#   'FL',
#   'WA',
#   'NJ',
#   'MD',
#   'MA',
#   'LA',
#   'CA',
#   'SC',
#   'MD',
#   'NY',
#   'SC',
#   'IL',
#   'PA',
#   'OH',
#   'NC',
#   'CA',
#   'FL',
#   'TN',
#   'GA',
#   'NJ',
#   'WI',
#   'CA',
#   'WA',
#   'MD',
#   'CA',
#   'OH',
#   'CA',
#   'CO',
#   'WA',
#   'NH',
#   'AK',
#   'TX',
#   'NY',
#   'CT',
#   'DC',
#   'OR',
#   'MO',
#   'MA',
#   'MI',
#   'MN',
#   'CA',
#   ...]}

# %%
for k,v in ranking_by_drg.items():
    while True:
        if len(v) >= 51:
            break
        v.append(None)

# %%
drg_by_id = {key.split(' - ')[0]: key for key in ranking_by_drg.keys()}
df_rank = pd.DataFrame(ranking_by_drg)

# %%
from collections import defaultdict

_df = pd.DataFrame(index=sql_df['Provider State'].unique())
for column in df_rank.columns:
    rankings_by_state = []

    if column in ['rank']:
        continue
        
    for rank, curr_state in zip(sql_df.index, df_rank[column]):
        rankings_by_state.append(curr_state)
    
    t = pd.DataFrame(rankings_by_state, columns=['State'])
    t['Rank'] = t.index
    t.set_index(['State'], inplace=True)
    
    _df = pd.merge(left=_df, right=t, how='left', left_index=True, right_index=True)
    
_df.columns = drg_by_id.keys()

# %%
_df.fillna(-100, inplace=True)
_df.head() #wherre -100 is not a rank but only a placeholder - shown as dark blue in the heatmap
# Out:
#     039  057  069
# AK  989  989  989
# AL   46   46   46
# AL   46   46   47
# AL   46   46   62
# AL   46   46   74

# %%
SELECTED_DRG =  drg_by_id['039']
SELECTED_PROVIDER_ID = None
SELECTED_DRG
# Out:
# '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC'

# %%
_df = sql_df[sql_df['DRG Definition'] == SELECTED_DRG]
_df.loc[:, 'Provider State'] = _df.loc[:, 'Provider State'].astype('category')
groupby_state = _df.groupby(by='Provider State').agg(['mean', 'min', 'max'])
groupby_state.reset_index(inplace=True)

# %%
#Based on the 95% confidence interval (the gray bar), costs appears 
#to be within a tight range across each state with the exception of MA and DC
plt.figure(figsize=(20,5))
sns.barplot(x='Provider State', y='Average Total Payments', data=sql_df)
plt.title('Avg. Cost and 95% CI for DRG = {}'.format(SELECTED_DRG), fontsize=20)
plt.xlabel('Average Cost ($)', fontsize=20)
plt.xlabel('Provider State', fontsize=20)
# Out:
# Text(0.5, 0, 'Provider State')

# %%
total_discharges_by_drg = dict()
for drg in sql_df['DRG Definition'].unique():

    query = """
        SELECT "Provider State" as providerState, SUM("Total Discharges") as numDischarges
        FROM drug_exp
        WHERE "DRG Definition" = '{drg}' 
        GROUP BY "Provider State"
    """.format(drg=drg)
    
    cursor = engine.execute(query)
    total_discharges_by_drg[drg] = [(record[0], record[1]) for record in cursor]

# %%
_df = pd.DataFrame(index=sql_df['Provider State'].unique())
for k,v in total_discharges_by_drg.items():
    t = pd.DataFrame(v, columns=['State', 'Total_Discharges'])
    t.set_index(['State'], inplace=True)
    _df = pd.merge(left=_df, right=t, how='left', left_index=True, right_index=True)
_df.columns = drg_by_id.keys()
_df.fillna(0, inplace=True)

# %%
_df
# Out:
#      039   057 069
# AL   879   575  32
# AK    23    11   0
# AZ   606   386   0
# CT   384   397   0
# AR   652   247   0
# CA  1715  1469   0
# CO   255   254   0
# DE   144   114   0
# DC    47   109   0
# FL  2847  2834   0
# IN  1078   833   0
# GA  1015   672   0
# HI    24    19   0
# ID   113    12   0
# IL  1240  1972   0
# IA   518   188   0
# KS   594   226   0
# KY   728   519   0
# LA   743   237   0
# ME   205   141   0
# MD   706  1280   0
# MA   732  1065   0
# MI  1325  1242   0
# MN   445   491   0
# MS   588   332   0
# TX  2871     0   0
# MO  1030   675   0
# MT   174    63   0
# NE   318   102   0
# NV   311   160   0
# NH   216   143   0
# NJ   819  1636   0
# NM   128    72   0
# NY  1336  3105   0
# NC  1141  1067   0
# ND   178    19   0
# OH  1186   764   0
# OK   463     0   0
# OR   354     0   0
# PA  1003     0   0
# RI    76     0   0
# SC   721     0   0
# SD   156     0   0
# TN   986     0   0
# UT   109     0   0
# VT    57     0   0
# VA   827     0   0
# WA   531     0   0
# WV   356     0   0
# WI   609     0   0
# WY    44     0   0

# %%
#Otherwise, cost appears to be consistent across states. Even expensive states (CA, NY) have low-cost options.
plt.figure(figsize=(20,5))
sns.swarmplot(x="Provider State", y='Average Total Payments', data=_df)
plt.title('Cost At Each Provider for DRG = {}'.format(SELECTED_DRG), fontsize=20)
plt.xlabel('Cost ($)', fontsize=20)
plt.xlabel('Provider State', fontsize=20)
# Out:
# Text(0.5, 0, 'Provider State')
